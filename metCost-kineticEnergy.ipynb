# %%
# %%capture
# %run '/Users/katbutler/MetabolicCost/metCostMod-Result.ipynb'

# %%
analyzed = set()
kePoints = []
eePoints = []
subjectName = []
index = 0
for subject in result.keys():   
    totalKE = 0
    # check if subject was already analyzed
    if subject[0] in analyzed:
        continue
        
    print(subject[0] + "\n" + "-----------")
    
    analyzed.add(subject[0])
    
    mNorm = (mass[index] / 82.2)
        
    index = index + 1
    

    Iw = 0.02654 * mNorm
    xw = np.nan_to_num((result[subject[0]]['Backwards']['APDM_Accel']['Data'][:, 5]), nan=0.0)
    yw = np.nan_to_num((result[subject[0]]['Backwards']['APDM_Accel']['Data'][:, 6]), nan=0.0)
    zw = np.nan_to_num((result[subject[0]]['Backwards']['APDM_Accel']['Data'][:, 7]), nan=0.0)

    omegaw = (xw**2 + yw**2 + zw**2)**0.5
    KEw = 0.5*Iw*omegaw**2
    KEw_df = pd.DataFrame(KEw, columns=['KE'])
    # print(KE_df)

    KE1w_df = KEw_df.iloc[46080:92160]
    KE1w_mean = round(KE1w_df.mean().values[0], 4)
    # print(f"KE1: {KE1w_mean}")

    KE2w_df = KEw_df.iloc[92160:138112]
    KE2w_mean = round(KE2w_df.mean().values[0], 4)
    # print(f"KE2: {KE2w_mean}")

    KE3w_df = KEw_df.iloc[138112:184064]
    KE3w_mean = round(KE3w_df.mean().values[0],4)
    # print(f"KE3: {KE3w_mean}")


    Ic = 0.33201 * mNorm
    xc = np.nan_to_num((result[subject[0]]['Backwards']['APDM_Accel']['Data'][:, 14]), nan=0.0)
    yc = np.nan_to_num((result[subject[0]]['Backwards']['APDM_Accel']['Data'][:, 15]), nan=0.0)
    zc = np.nan_to_num((result[subject[0]]['Backwards']['APDM_Accel']['Data'][:, 16]), nan=0.0)

    omegac = (xc**2 + yc**2 + zc**2)**0.5
    KEc = 0.5*Ic*omegac**2
    KEc_df = pd.DataFrame(KEc, columns=['KE'])
    # print(KE_df)

    KE1c_df = KEc_df.iloc[46080:92160]
    KE1c_mean = round(KE1c_df.mean().values[0], 4)
    # print(f"KE1: {KE1c_mean}")

    KE2c_df = KEc_df.iloc[92160:138112]
    KE2c_mean = round(KE2c_df.mean().values[0], 4)
    # print(f"KE2: {KE2c_mean}")

    KE3c_df = KEc_df.iloc[138112:184064]
    KE3c_mean = round(KE3c_df.mean().values[0],4)
    # print(f"KE3: {KE3c_mean}")



    Ial= 0.06397 * mNorm
    xal = np.nan_to_num((result[subject[0]]['Backwards']['APDM_Accel']['Data'][:, 23]), nan=0.0)
    yal = np.nan_to_num((result[subject[0]]['Backwards']['APDM_Accel']['Data'][:, 24]), nan=0.0)
    zal = np.nan_to_num((result[subject[0]]['Backwards']['APDM_Accel']['Data'][:, 25]), nan=0.0)

    omegaal = (xal**2 + yal**2 + zal**2)**0.5
    KEal = 0.5*Iw*omegaal**2
    KEal_df = pd.DataFrame(KEal, columns=['KE'])
    # print(KE_df)

    KE1al_df = KEal_df.iloc[46080:92160]
    KE1al_mean = round(KE1al_df.mean().values[0], 4)
    # print(f"KE1: {KE1al_mean}")

    KE2al_df = KEal_df.iloc[92160:138112]
    KE2al_mean = round(KE2al_df.mean().values[0], 4)
    # print(f"KE2: {KE2al_mean}")

    KE3al_df = KEal_df.iloc[138112:184064]
    KE3al_mean = round(KE3al_df.mean().values[0],4)
    # print(f"KE3: {KE3al_mean}")


    Iar = 0.06271 * mNorm
    xar = np.nan_to_num((result[subject[0]]['Backwards']['APDM_Accel']['Data'][:, 32]), nan=0.0)
    yar = np.nan_to_num((result[subject[0]]['Backwards']['APDM_Accel']['Data'][:, 33]), nan=0.0)
    zar = np.nan_to_num((result[subject[0]]['Backwards']['APDM_Accel']['Data'][:, 34]), nan=0.0)

    omegaar = (xar**2 + yar**2 + zar**2)**0.5
    KEar = 0.5*Iw*omegaar**2
    KEar_df = pd.DataFrame(KEar, columns=['KE'])
    # print(KE_df)

    KE1ar_df = KEar_df.iloc[46080:92160]
    KE1ar_mean = KE1ar_df.mean().values[0]
    # print(f"KE1: {KE1ar_mean}")

    KE2ar_df = KEar_df.iloc[92160:138112]
    KE2ar_mean = KE2ar_df.mean().values[0]
    # print(f"KE2: {KE2ar_mean}")

    KE3ar_df = KEar_df.iloc[138112:184064]
    KE3ar_mean = KE3ar_df.mean().values[0]
    # print(f"KE3: {KE3ar_mean}")


    # timeCoords = result['Subject01']['Walking']['Metabolics_System']['Data'][indShift, 0]

    timeF = result[subject[0]]['Backwards']['APDM_Accel']['Data'][:,0]

    zeros = {
        'Switch': [46080,92160,138112,184064]
    }

    KE = KEw + KEc + KEal + KEar


    zeros_df = pd.DataFrame(zeros)
    time_slice = timeF[46080:184064]
    KE_slice = KE[46080:184064]
    print(KE1w_mean)
    print(KE1ar_mean)
    KE1_mean = round(KE1w_mean + KE1ar_mean + KE1al_mean + KE1c_mean, 4)
    KE2_mean = round(KE2w_mean + KE2ar_mean + KE2al_mean + KE2c_mean, 4)
    KE3_mean = round(KE3w_mean + KE3ar_mean + KE3al_mean + KE3c_mean, 4)

    kePoints.append(KE1_mean)
    subjectName.append(subject[0])
    kePoints.append(KE2_mean)
    subjectName.append(subject[0])
    kePoints.append(KE3_mean)
    subjectName.append(subject[0])
    
    ke_slice_start = result[subject[0]]['Backwards']['Metabolics_System']['Data'][0, 0] + 46080 / 128
    ke_slice_end = result[subject[0]]['Backwards']['Metabolics_System']['Data'][0, 0] + 184064 / 128

    VO2 = result[subject[0]]['Backwards']['Metabolics_System']['Data'][:,vo2]
    VCO2 = result[subject[0]]['Backwards']['Metabolics_System']['Data'][:,vco2]

    EE = (16.58*VO2 + 4.15*VCO2)/mass[0]
    EE_ground = np.zeros(np.size(EE))

    ind = result[subject[0]]['Backwards']['Metabolics_System']['Data'][:,code]
    ind = ind[0:-1] - ind[1:]
    bool_ind = ind != 0.

    indShift = np.where(bool_ind)[0] # last index for each phase
    indShift = np.concatenate((indShift, [len(ind)]))

    for i in range(0,len(indShift)):
        T = result[subject[0]]['Backwards']['Metabolics_System']['Data'][indShift[i],0]
        timeM3 = T - (3*60)
        bool_time = result[subject[0]]['Backwards']['Metabolics_System']['Data'][:,0] < timeM3
        threeMin = indShift[i] - np.max(np.where(bool_time)[0])

        if i == 0:
            EE_ground[0:indShift[i]] = np.mean(EE[indShift[i]-threeMin:indShift[i]])
            ee1 = round(np.mean(EE[indShift[i]-threeMin:indShift[i]]), 4)
            if ke_slice_start <= T <= ke_slice_end:
                eePoints.append(ee1)

        elif i == len(indShift)-1:
            EE_ground[indShift[i-1]:] = np.mean(EE[-threeMin:])
            ee2 = round(np.mean(EE[-threeMin:]), 4)
            if ke_slice_start <= T <= ke_slice_end:
                eePoints.append(ee2)

        else:
            EE_ground[indShift[i-1]:indShift[i]+1] = np.mean(EE[indShift[i]-threeMin:indShift[i]])
            ee3 = round(np.mean(EE[indShift[i]-threeMin:indShift[i]]), 4)
            if ke_slice_start <= T <= ke_slice_end:
                eePoints.append(ee3)

    x = [360,720,1079,1438]
    y = [KE1_mean,KE2_mean,KE3_mean,KE3_mean] 

    fig, ax1 = plt.subplots() 

    color = 'tab:blue'
    ax1.set_xlabel('Time (s)') 
    ax1.set_ylabel('Kinetic Energy (W/kg)', color = color)
    ax1.plot(time_slice, KE_slice, color= color)
    ax1.tick_params(axis ='y', labelcolor = color)
    
    valid_indices = zeros_df['Switch'][zeros_df['Switch'] < len(timeF)]
    time_eeGround = result[subject[0]]['Backwards']['Metabolics_System']['Data'][:, 0]
    
    plt.scatter(timeF[valid_indices], [0]*len(valid_indices), color='black', marker='o')
    plt.step(x, y, where='post',color='black')
    for i in range(len(x) - 1):
        plt.text(x[i] + 200, y[i] + 0.02, f'{y[i]}', ha='center', va='bottom')

    ax2 = ax1.twinx() 

    color = 'tab:orange'
    ax2.set_ylabel('EE Ground (W/kg)', color = color) 
    ax2.plot(time_eeGround, EE_ground, '-', label='EE_ground', color= color)
    ax2.tick_params(axis ='y', labelcolor = color) 

    plt.xlabel('time (s)')
    plt.title('Kinetic Energy vs. EE Ground')
    plt.show()

eePoints.insert(4, 3.3625)
eePoints.insert(5, 3.3625)
kePoints[4] = 0.0864
kePoints[5] = 0.0864
# Out:
# Subject01
# -----------
# 0.0015
# 0.022252358043317984
# posx and posy should be finite values
# Subject02
# -----------
# 0.0014
# 0.02750339489115763
# posx and posy should be finite values
# Subject03
# -----------
# 0.0056
# 0.0502616155546625
# Subject04
# -----------
# 0.0024
# 0.026375834428547643
# Subject05
# -----------
# 0.0037
# 0.021641429303226385
# Subject06
# -----------
# 0.0023
# 0.017763991266798056
# Subject07
# -----------
# 0.0051
# 0.0655379691122355
# Subject08
# -----------
# 0.0033
# 0.04879145177357414
# Subject09
# -----------
# 0.0023
# 0.044140523792894605
# Subject10
# -----------
# 0.002
# 0.034876948756022035

# %%
x = eePoints
y = kePoints
print(x)
print(y)
plt.scatter(x, y)
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)))
plt.xlabel('EE (W/kg)')
plt.ylabel('KE (W/kg)')

coefficients = np.polyfit(x, y, 1)

correlationDf = pd.DataFrame(list(zip(x, y, subjectName)), columns=['EE', 'KE', 'Subject'])
correlationDf['Coefficient'] = correlationDf['EE']/correlationDf['KE']
display(correlationDf)
# Out:
# [3.1952, 4.1909, 5.2096, 3.3625, 3.3625, 3.3625, 5.0482, 4.0915, 2.2842, 3.1396, 4.0111, 1.8033, 4.1817, 5.3357, 6.7529, 3.789, 5.022, 2.0112, 5.0945, 4.1906, 2.1595, 3.4496, 2.8666, 1.4083, 3.8243, 2.9447, 1.2302, 3.2615, 3.7771, 1.4255]
# [0.0698, 0.1358, 0.2169, 0.0668, 0.0864, 0.0864, 0.2513, 0.1641, 0.0075, 0.076, 0.151, 0.009, 0.0866, 0.1474, 0.2286, 0.0602, 0.1162, 0.0095, 0.2094, 0.1212, 0.0127, 0.1629, 0.0781, 0.007, 0.1252, 0.0634, 0.0095, 0.1241, 0.2195, 0.0112]
#         EE      KE    Subject  Coefficient
# 0   3.1952  0.0698  Subject01    45.776504
# 1   4.1909  0.1358  Subject01    30.860825
# 2   5.2096  0.2169  Subject01    24.018442
# 3   3.3625  0.0668  Subject02    50.336826
# 4   3.3625  0.0864  Subject02    38.917824
# 5   3.3625  0.0864  Subject02    38.917824
# 6   5.0482  0.2513  Subject03    20.088341
# 7   4.0915  0.1641  Subject03    24.932968
# 8   2.2842  0.0075  Subject03   304.560000
# 9   3.1396  0.0760  Subject04    41.310526
# 10  4.0111  0.1510  Subject04    26.563576
# 11  1.8033  0.0090  Subject04   200.366667
# 12  4.1817  0.0866  Subject05    48.287529
# 13  5.3357  0.1474  Subject05    36.198779
# 14  6.7529  0.2286  Subject05    29.540245
# 15  3.7890  0.0602  Subject06    62.940199
# 16  5.0220  0.1162  Subject06    43.218589
# 17  2.0112  0.0095  Subject06   211.705263
# 18  5.0945  0.2094  Subject07    24.329035
# 19  4.1906  0.1212  Subject07    34.575908
# 20  2.1595  0.0127  Subject07   170.039370
# 21  3.4496  0.1629  Subject08    21.176182
# 22  2.8666  0.0781  Subject08    36.704225
# 23  1.4083  0.0070  Subject08   201.185714
# 24  3.8243  0.1252  Subject09    30.545527
# 25  2.9447  0.0634  Subject09    46.446372
# 26  1.2302  0.0095  Subject09   129.494737
# 27  3.2615  0.1241  Subject10    26.281225
# 28  3.7771  0.2195  Subject10    17.207745
# 29  1.4255  0.0112  Subject10   127.276786

# %%
subKE = correlationDf

colors = ['red', 'green', 'blue', 'orange', 'purple', 'brown', 'cyan', 'magenta', 'yellow', 'black']

for i in range(0, len(x), 3):
    plt.scatter(subKE['EE'][i:i+3], subKE['KE'][i:i+3], color=colors[i // 3], label=f'S{i//3 + 1}')

    coeffs = np.polyfit(x[i:i+3], y[i:i+3], 1)  # Linear fit
    slope = round(coeffs[0],4)
    print(f'Subject {i//3 + 1} Slope: {slope}')
    poly = np.poly1d(coeffs)
    x_fit = np.linspace(min(x[i:i+3]), max(x[i:i+3]), 100)
    y_fit = poly(x_fit)
    plt.plot(x_fit, y_fit, color=colors[i // 3], linestyle='-')
    
plt.legend()
plt.xlabel('EE (W/kg)')
plt.ylabel('KE (W/kg)')
plt.title('EE vs. KE by Subject - Backwards Walking')
plt.show()
# Out:
# Subject 1 Slope: 0.073
# Subject 2 Slope: 0.0119
# Subject 3 Slope: 0.088
# Subject 4 Slope: 0.0631
# Subject 5 Slope: 0.0553
# Subject 6 Slope: 0.035
# Subject 7 Slope: 0.0647
# Subject 8 Slope: 0.0711
# Subject 9 Slope: 0.0428
# Subject 10 Slope: 0.0814
# /var/folders/nt/kl5prt3s1z3dddnktbk561f00000gn/T/ipykernel_15116/1161538358.py:8: RankWarning: Polyfit may be poorly conditioned
#   coeffs = np.polyfit(x[i:i+3], y[i:i+3], 1)  # Linear fit

# %%
analyzed = set()
kePoints = []
eePoints = []
subjectName = []
index = 0
for subject in result.keys():   
    totalKE = 0

    # check if subject was already analyzed
    if subject[0] in analyzed:
        continue
        
    print(subject[0] + "\n" + "-----------")
    
    analyzed.add(subject[0])
    
    mNorm = (mass[index] / 82.2)
    index = index + 1
    
    Iw = 0.02654 * mNorm
    xw = np.nan_to_num((result[subject[0]]['Incline']['APDM_Accel']['Data'][:, 5]), nan=0.0)
    yw = np.nan_to_num((result[subject[0]]['Incline']['APDM_Accel']['Data'][:, 6]), nan=0.0)
    zw = np.nan_to_num((result[subject[0]]['Incline']['APDM_Accel']['Data'][:, 7]), nan=0.0)

    omegaw = (xw**2 + yw**2 + zw**2)**0.5
    KEw = 0.5*Iw*omegaw**2
    KEw_df = pd.DataFrame(KEw, columns=['KE'])
    # print(KE_df)

    KE1w_df = KEw_df.iloc[42960:92160]
    KE1w_mean = KE1w_df.mean().values[0]
    KE2w_df = KEw_df.iloc[92160:137728]
    KE2w_mean = KE2w_df.mean().values[0]
    KE3w_df = KEw_df.iloc[137728:184320]
    KE3w_mean = KE3w_df.mean().values[0]
    KE4w_df = KEw_df.iloc[184320:230400]
    KE4w_mean = KE4w_df.mean().values[0]
    KE5w_df = KEw_df.iloc[230400:276224]
    KE5w_mean = KE5w_df.mean().values[0]
    KE6w_df = KEw_df.iloc[276224:322560]
    KE6w_mean = KE6w_df.mean().values[0]


    Ic = 0.33201 * mNorm
    xc = np.nan_to_num((result[subject[0]]['Incline']['APDM_Accel']['Data'][:, 14]), nan=0.0)
    yc = np.nan_to_num((result[subject[0]]['Incline']['APDM_Accel']['Data'][:, 15]), nan=0.0)
    zc = np.nan_to_num((result[subject[0]]['Incline']['APDM_Accel']['Data'][:, 16]), nan=0.0)

    omegac = (xc**2 + yc**2 + zc**2)**0.5
    KEc = 0.5*Ic*omegac**2
    KEc_df = pd.DataFrame(KEc, columns=['KE'])
    # print(KE_df)

    KE1c_df = KEc_df.iloc[42960:92160]
    KE1c_mean = KE1c_df.mean().values[0]
    KE2c_df = KEc_df.iloc[92160:137728]
    KE2c_mean = KE2c_df.mean().values[0]
    KE3c_df = KEc_df.iloc[137728:184320]
    KE3c_mean = KE3c_df.mean().values[0]
    KE4c_df = KEc_df.iloc[184320:230400]
    KE4c_mean = KE4c_df.mean().values[0]
    KE5c_df = KEc_df.iloc[230400:276224]
    KE5c_mean = KE5c_df.mean().values[0]
    KE6c_df = KEc_df.iloc[276224:322560]
    KE6c_mean = KE6c_df.mean().values[0]



    Ial= 0.06397 * mNorm
    xal = np.nan_to_num((result[subject[0]]['Incline']['APDM_Accel']['Data'][:, 23]), nan=0.0)
    yal = np.nan_to_num((result[subject[0]]['Incline']['APDM_Accel']['Data'][:, 24]), nan=0.0)
    zal = np.nan_to_num((result[subject[0]]['Incline']['APDM_Accel']['Data'][:, 25]), nan=0.0)

    omegaal = (xal**2 + yal**2 + zal**2)**0.5
    KEal = 0.5*Iw*omegaal**2
    KEal_df = pd.DataFrame(KEal, columns=['KE'])
    # print(KE_df)

    KE1al_df = KEal_df.iloc[42960:92160]
    KE1al_mean = KE1al_df.mean().values[0]
    KE2al_df = KEal_df.iloc[92160:137728]
    KE2al_mean = KE2al_df.mean().values[0]
    KE3al_df = KEal_df.iloc[137728:184320]
    KE3al_mean = KE3al_df.mean().values[0]
    KE4al_df = KEal_df.iloc[184320:230400]
    KE4al_mean = KE4al_df.mean().values[0]
    KE5al_df = KEal_df.iloc[230400:276224]
    KE5al_mean = KE5al_df.mean().values[0]
    KE6al_df = KEal_df.iloc[276224:322560]
    KE6al_mean = KE6al_df.mean().values[0]


    Iar = 0.06271 * mNorm
    xar = np.nan_to_num((result[subject[0]]['Incline']['APDM_Accel']['Data'][:, 32]), nan=0.0)
    yar = np.nan_to_num((result[subject[0]]['Incline']['APDM_Accel']['Data'][:, 33]), nan=0.0)
    zar = np.nan_to_num((result[subject[0]]['Incline']['APDM_Accel']['Data'][:, 34]), nan=0.0)

    omegaar = (xar**2 + yar**2 + zar**2)**0.5
    KEar = 0.5*Iw*omegaar**2
    KEar_df = pd.DataFrame(KEar, columns=['KE'])
    # print(KE_df)

    KE1ar_df = KEar_df.iloc[42960:92160]
    KE1ar_mean = KE1ar_df.mean().values[0]
    KE2ar_df = KEar_df.iloc[92160:137728]
    KE2ar_mean = KE2ar_df.mean().values[0]
    KE3ar_df = KEar_df.iloc[137728:184320]
    KE3ar_mean = KE3ar_df.mean().values[0]
    KE4ar_df = KEar_df.iloc[184320:230400]
    KE4ar_mean = KE4ar_df.mean().values[0]
    KE5ar_df = KEar_df.iloc[230400:276224]
    KE5ar_mean = KE5ar_df.mean().values[0]
    KE6ar_df = KEar_df.iloc[276224:322560]
    KE6ar_mean = KE6ar_df.mean().values[0]
    # timeCoords = result['Subject01']['Walking']['Metabolics_System']['Data'][indShift, 0]

    timeF = result[subject[0]]['Incline']['APDM_Accel']['Data'][:,0]

    zeros = {
        'Switch': [42960,92160,137728,184320,230400,276224,322560]
    }

    KE = KEw + KEc + KEal + KEar


    zeros_df = pd.DataFrame(zeros)
    time_slice = timeF[42960:322560]
    KE_slice = KE[42960:322560]

    KE1_mean = round(KE1w_mean + KE1ar_mean + KE1al_mean + KE1c_mean, 4)
    KE2_mean = round(KE2w_mean + KE2ar_mean + KE2al_mean + KE2c_mean, 4)
    KE3_mean = round(KE3w_mean + KE3ar_mean + KE3al_mean + KE3c_mean, 4)
    KE4_mean = round(KE4w_mean + KE4ar_mean + KE4al_mean + KE4c_mean, 4)
    KE5_mean = round(KE5w_mean + KE5ar_mean + KE5al_mean + KE5c_mean, 4)
    
    kePoints.append(KE1_mean)
    subjectName.append(subject[0])
    kePoints.append(KE2_mean)
    subjectName.append(subject[0])
    # kePoints.append(KE3_mean)
    kePoints.append(KE4_mean)
    subjectName.append(subject[0])
    kePoints.append(KE5_mean)
    subjectName.append(subject[0])
    
    ke_slice_start = result[subject[0]]['Incline']['Metabolics_System']['Data'][0, 0] + 42960 / 128
    ke_slice_end = result[subject[0]]['Incline']['Metabolics_System']['Data'][0, 0] + 322560 / 128

    VO2 = result[subject[0]]['Incline']['Metabolics_System']['Data'][:,vo2]
    VCO2 = result[subject[0]]['Incline']['Metabolics_System']['Data'][:,vco2]

    EE = (16.58*VO2 + 4.15*VCO2)/mass[0]
    EE_ground = np.zeros(np.size(EE))

    ind = result[subject[0]]['Incline']['Metabolics_System']['Data'][:,code]
    ind = ind[0:-1] - ind[1:]
    bool_ind = ind != 0.

    indShift = np.where(bool_ind)[0] # last index for each phase
    indShift = np.concatenate((indShift, [len(ind)]))

    for i in range(1, len(indShift)-1):
        T = result[subject[0]]['Incline']['Metabolics_System']['Data'][indShift[i], 0]
        timeM3 = T - (3 * 60)
        bool_time = result[subject[0]]['Incline']['Metabolics_System']['Data'][:, 0] < timeM3
        threeMin = indShift[i] - np.max(np.where(bool_time)[0])

        if i == 0:
            EE_ground[0:indShift[i]] = np.mean(EE[indShift[i] - threeMin:indShift[i]])
            ee1 = round(np.mean(EE[indShift[i] - threeMin:indShift[i]]), 4)
            # if ke_slice_start <= T <= ke_slice_end:
                # eePoints.append(ee1)
        elif i == 1:
            EE_ground[indShift[i-1]:indShift[i]] = np.mean(EE[indShift[i] - threeMin:indShift[i]])
            ee2 = round(np.mean(EE[indShift[i] - threeMin:indShift[i]]), 4)
            if ke_slice_start <= T <= ke_slice_end:
                eePoints.append(ee2)
        elif i == 2:
            EE_ground[indShift[i-1]:indShift[i]] = np.mean(EE[indShift[i] - threeMin:indShift[i]])
            ee3 = round(np.mean(EE[indShift[i] - threeMin:indShift[i]]), 4)
            if ke_slice_start <= T <= ke_slice_end:
                eePoints.append(ee3)
        elif i == 3:
            EE_ground[indShift[i-1]:indShift[i]] = np.mean(EE[indShift[i] - threeMin:indShift[i]])
            ee4 = round(np.mean(EE[indShift[i] - threeMin:indShift[i]]), 4)
            # if ke_slice_start <= T <= ke_slice_end:
                # eePoints.append(ee4)
        elif i == 4:
            EE_ground[indShift[i-1]:indShift[i]] = np.mean(EE[indShift[i] - threeMin:indShift[i]])
            ee4 = round(np.mean(EE[indShift[i] - threeMin:indShift[i]]), 4)
            if ke_slice_start <= T <= ke_slice_end:
                eePoints.append(ee4)
        else:
            EE_ground[indShift[i-1]:indShift[i] + 1] = np.mean(EE[indShift[i] - threeMin:indShift[i]])
            ee5 = round(np.mean(EE[indShift[i] - threeMin:indShift[i]]), 4)
            if ke_slice_start <= T <= ke_slice_end:
                eePoints.append(ee5)
                

    x = [358, 720, 1076, 1440, 1800, 2158]
    y = [KE1_mean, KE2_mean, KE3_mean, KE4_mean, KE5_mean, KE5_mean] 

    fig, ax1 = plt.subplots() 

    color = 'tab:blue'
    ax1.set_xlabel('Time (s)') 
    ax1.set_ylabel('Kinetic Energy (W)', color = color)
    ax1.plot(timeF, KE, color= color)
    ax1.tick_params(axis ='y', labelcolor = color)
    
    valid_indices = zeros_df['Switch'][zeros_df['Switch'] < len(timeF)]
    time_eeGround = result[subject[0]]['Incline']['Metabolics_System']['Data'][:, 0]
    
    plt.scatter(timeF[valid_indices], [0]*len(valid_indices), color='black', marker='o')
    plt.step(x, y, where='post',color='black')
    for i in range(len(x) - 1):
        plt.text(x[i] + 200, y[i] + 0.02, f'{y[i]}', ha='center', va='bottom')

    ax2 = ax1.twinx() 

    color = 'tab:orange'
    ax2.set_ylabel('EE Ground (W/kg)', color = color) 
    ax2.plot(time_eeGround, EE_ground, '-', label='EE_ground', color= color)
    ax2.tick_params(axis ='y', labelcolor = color) 

    plt.xlabel('time (s)')
    plt.title('Kinetic Energy vs. EE Ground')
    plt.show()

# %%
x = eePoints
y = kePoints
print(len(x))
print(len(y))
print(eePoints)
coefficients = np.polyfit(x, y, 1)

correlationDf = pd.DataFrame(list(zip(x, y, subjectName)), columns=['EE', 'KE','Subject'])
correlationDf['Coefficient'] = correlationDf['EE']/correlationDf['KE']
display(correlationDf)

# %%
subKE = correlationDf
print('SOLID LINES ARE INCLINE 4, DASHED ARE INCLINE 9')
colors = ['red', 'green', 'blue', 'orange', 'purple', 'brown', 'cyan', 'magenta', 'yellow', 'black']
lineStyles = ['-','-.']
for i in range(0, len(x), 2):
    subjectNum = i // 4 + 1
    
    if i % 4 == 0:  # Incline 4
        label = f'S{subjectNum}'
        LS = lineStyles[0]
    else:  # Incline 9
        label = None
        LS = lineStyles[1]
    
    plt.scatter(subKE['EE'][i:i+4], subKE['KE'][i:i+4], color=colors[i // 4], label=label)
        
    coeffs = np.polyfit(x[i:i+2], y[i:i+2], 1)  # Linear fit
    slope = round(coeffs[0],4)
    if (i % 4) == 0:
        print(f'Subject {i//4 + 1} Incline 4, Slope: {slope}')
    else:
        print(f'Subject {i//4 + 1} Incline 9, Slope: {slope}')
    poly = np.poly1d(coeffs)
    x_fit = np.linspace(min(x[i:i+4]), max(x[i:i+4]), 100)
    y_fit = poly(x_fit)
    plt.plot(x_fit, y_fit, color=colors[i // 4], linestyle=LS)
    
plt.legend()
plt.ylim(0, 0.65)
plt.xlabel('EE [W/kg]')
plt.ylabel('KE [W]')
plt.title('EE vs. KE by Subject and Incline - Incline')
plt.show()

# %%
subKE = correlationDf
colors = ['red', 'green', 'blue', 'orange', 'purple', 'brown', 'cyan', 'magenta', 'yellow', 'black']
lineStyles = ['-','-.']

# Plot for Incline 4
plt.figure(figsize=(10, 6))
for i in range(0, len(x), 4):  
    subjectNum = i // 4 + 1
    label = f'S{subjectNum}'
    LS = lineStyles[0]
    
    plt.scatter(subKE['EE'][i:i+2], subKE['KE'][i:i+2], color=colors[i // 4], label=label)
        
    coeffs = np.polyfit(x[i:i+2], y[i:i+2], 1)  
    slope = round(coeffs[0], 4)
    print(f'Subject {subjectNum} Incline 4, Slope: {slope}')
    
    poly = np.poly1d(coeffs)
    x_fit = np.linspace(min(x[i:i+2]), max(x[i:i+2]), 100)
    y_fit = poly(x_fit)
    plt.plot(x_fit, y_fit, color=colors[i // 4], linestyle=LS)

plt.legend()
plt.ylim(0, 0.65)
plt.xlabel('EE [W/kg]')
plt.ylabel('KE [W]')
plt.title('EE vs. KE by Subject - Incline 4')
plt.show()

# Plot for Incline 9
plt.figure(figsize=(10, 6))
for i in range(2, len(x), 4): 
    subjectNum = i // 4 + 1
    label = f'S{subjectNum}' if i % 4 == 2 else None
    LS = lineStyles[0]
    
    plt.scatter(subKE['EE'][i:i+2], subKE['KE'][i:i+2], color=colors[i // 4], label=label)
        
    coeffs = np.polyfit(x[i:i+2], y[i:i+2], 1)  
    slope = round(coeffs[0], 4)
    print(f'Subject {subjectNum} Incline 9, Slope: {slope}')
    
    poly = np.poly1d(coeffs)
    x_fit = np.linspace(min(x[i:i+2]), max(x[i:i+2]), 100)
    y_fit = poly(x_fit)
    plt.plot(x_fit, y_fit, color=colors[i // 4], linestyle=LS)

plt.legend()
plt.ylim(0, 0.65)
plt.xlabel('EE [W/kg]')
plt.ylabel('KE [W]')
plt.title('EE vs. KE by Subject - Incline 9')
plt.show()

# %%
analyzed = set()
dfCount = 1
for subject in result.keys():
    indShiftDict = {}
    if subject[0] in analyzed:
        continue
    analyzed.add(subject[0])
    for activity in result.keys():
    
        if activity[1] in indShiftDict:
            continue
            
        if activity[1] not in result[subject[0]]:
            continue

        ind = result[subject[0]][activity[1]]['APDM_Accel']['Data'][:, code]
        indShift = np.where((ind[:-1] - ind[1:]) != 0)[0]
        
        
        indShiftDict[activity[1]] = indShift

    # Convert to DataFrame for the subject
    indDFKe = pd.DataFrame(dict([(key, pd.Series(value)) for key, value in indShiftDict.items()]))
    indDFKe = indDFKe.fillna(0)
    
    if dfCount <= 10:
        if dfCount < 10:
            exec(f"Subject0{dfCount} = indDFKe")
            dfCount += 1
        else:
            exec(f"Subject{dfCount} = indDFKe")
            dfCount += 1
    
print(Subject01)
# Out:
#    Backwards   Cycling  Incline   Running   Walking
# 0    46080.0   46080.0    46080   46080.0   46080.0
# 1    92162.0   92162.0    92162   92162.0   92162.0
# 2   138244.0  138244.0   138244  138244.0  138244.0
# 3   184326.0  184326.0   184326  184326.0  184326.0
# 4        0.0  230408.0   230408       0.0       0.0
# 5        0.0       0.0   276489       0.0       0.0

# %%
analyzed = set()
kePoints = []
eePoints = []
subjectName = []
index = -1

for subject in result.keys():

    KE_df= pd.DataFrame()
    # print(KE_df)

    if subject[0] not in analyzed:
        index += 1
    analyzed.add(subject[0])
    
    print(f"{subject[0]}\n-----------")
    
    indDF = globals()[subject[0]].astype(int)
    mNorm = mass[index] / 82.2

    if subject[1] in ['Backwards2', 'Cycling2']:
        continue
    # if subject[0] is 'Subject02' and subject[1] is 'Backwards':
    #     continue

    # Parameters for different segments
    segments = [
        {'Name': 'W','I': 0.02654, 'columns': [5, 6, 7]},   # W
        {'Name': 'C', 'I': 0.33201, 'columns': [14, 15, 16]}, # C
        {'Name': 'AL', 'I': 0.06397, 'columns': [23, 24, 25]}, # AL
        {'Name': 'AR', 'I': 0.06271, 'columns': [32, 33, 34]}  # AR
    ]


    for segment in segments:
        
        segment_name = segment['Name']
        I = segment['I'] * mNorm
        cols = segment['columns']

        # Extract and compute omega
        x, y, z = [np.nan_to_num(result[subject[0]][subject[1]]['APDM_Accel']['Data'][:, c], nan=0.0) for c in cols]
        omega = np.sqrt(x**2 + y**2 + z**2)

        # Compute kinetic energy
        KE = 0.5 * I * omega**2
        KE_df[segment_name] = KE
        # display(KE_df)
        
    KEm_df = pd.DataFrame() 
    for i in range(len(indDF[subject[1]]) - 1):
        KEm_df = KE_df.loc[indDF[subject[1]][i]:indDF[subject[1]][i+1]].mean()
        display(KEm_df)
        KEm_df['total'] = (KEm_df['W'] + KEm_df['C'] + KEm_df['AL'] + KEm_df['AR']) * mNorm
        
    # KEm_df['total'] = (KEm_df['W'] + KEm_df['C'] + KEm_df['AL'] + KEm_df['AR']) * mNorm

    # KE_means_df = pd.DataFrame()
    # # print(KE_means)
    # for i in range(len(indDF[subject[1]]) - 1):
    #     KE_means = KE_df.loc[indDF[subject[1]][i]:indDF[subject[1]][i+1], 'total'].mean()
    #     KE_means_df['KE'] = KE_means
    #     print(KE_means_df)

    # Energy expenditure calculations
    timeF = result[subject[0]][subject[1]]['APDM_Accel']['Data'][:, 0]
    ke_slice_start = result[subject[0]][subject[1]]['APDM_Accel']['Data'][0, 0] + indDF[subject[1]][0] / 128
    ke_slice_end = result[subject[0]][subject[1]]['APDM_Accel']['Data'][0, 0] + indDF[subject[1]][5] / 128

    # Calculate EE ground values
    VO2 = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, vo2]
    VCO2 = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, vco2]
    EE = (16.58 * VO2 + 4.15 * VCO2) / mass[0]
    EE_ground = np.zeros(np.size(EE))

    ind = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, code]
    ind = ind[:-1] - ind[1:]
    bool_ind = ind != 0.0
    indShift = np.where(bool_ind)[0]  # Last index for each phase
    indShift = np.concatenate((indShift, [len(ind)]))
    
    for i in range(len(indShift)):
        T = result[subject[0]][subject[1]]['Metabolics_System']['Data'][indShift[i], 0]
        timeM3 = T - (3 * 60)
        bool_time = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, 0] < timeM3
        threeMin = indShift[i] - np.max(np.where(bool_time)[0])

        if i == 0:
            EE_ground[0:indShift[i]] = np.mean(EE[indShift[i] - threeMin : indShift[i]])
            eePoints.append(round(np.mean(EE[indShift[i] - threeMin : indShift[i]]), 4))
        elif i == len(indShift) - 1:
            EE_ground[indShift[i - 1] :] = np.mean(EE[-threeMin:])
            eePoints.append(round(np.mean(EE[-threeMin:]), 4))
        else:
            EE_ground[indShift[i - 1] : indShift[i] + 1] = np.mean(EE[indShift[i] - threeMin : indShift[i]])
            eePoints.append(round(np.mean(EE[indShift[i] - threeMin : indShift[i]]), 4))
    # print(eePoints)
    # Visualization
    # KE = sum(total_KE_means) * mNorm
    lastNZ = indDF[subject[1]][indDF[subject[1]] != 0].index[-1]
    time_slice = timeF[indDF[subject[1]][0]:indDF[subject[1]][lastNZ]]
    KE_slice = KE[indDF[subject[1]][0]:indDF[subject[1]][lastNZ]]
    # print(indDF[subject[1]])
    # print(KE[0:17000])

    fig, ax1 = plt.subplots()
    color = 'tab:blue'
    ax1.set_xlabel('Time (s)')
    ax1.set_ylabel('Kinetic Energy (W/kg)', color=color)
    ax1.plot(time_slice, KE_slice, color=color)
    ax1.tick_params(axis='y', labelcolor=color)

    ax2 = ax1.twinx()
    color = 'tab:orange'
    ax2.set_ylabel('EE Ground (W/kg)', color=color)
    ax2.plot(result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, 0], EE_ground, '-', color=color)
    ax2.tick_params(axis='y', labelcolor=color)

    plt.xlabel('Time (s)')
    plt.title('Kinetic Energy vs. EE Ground')
    plt.show()

# %%
# 6 min average
analyzed = set()
subjectName = []
index = -1
df_list = []

for subject in result.keys():
    # Skip certain activities
    if subject[0] == "Subject02" and subject[1] in ['Backwards','Backwards2']:
        continue
    if subject[0] == "Subject05" and subject[1] in ['Cycling','Cycling2']:
        continue
    kePoints = []
    eePoints = []
    # Initialize/reset DataFrames for each subject
    KE_df = pd.DataFrame()
    KE_means_df = pd.DataFrame(columns=["Segment", "KE_Mean"])
    
    mNorm = mass[index] / 82.2
    
    if subject[0] not in analyzed:
        index += 1
    print(f"{subject[0]} {subject[1]}\n-----------")
    analyzed.add(subject[0])
    

    indDF = globals()[subject[0]].astype(int)


    # Parameters for different segments
    segments = [
        {'Name': 'W', 'I': 0.02654, 'columns': [5, 6, 7]},    # W
        {'Name': 'C', 'I': 0.33201, 'columns': [14, 15, 16]}, # C
        {'Name': 'AL', 'I': 0.06397, 'columns': [23, 24, 25]}, # AL
        {'Name': 'AR', 'I': 0.06271, 'columns': [32, 33, 34]}  # AR
    ]

    # Calculate kinetic energy for each segment
    for segment in segments:
        segment_name = segment['Name']
        I = segment['I'] * mNorm
        cols = segment['columns']
        
        # Extract and compute omega
        x, y, z = [np.nan_to_num(result[subject[0]][subject[1]]['APDM_Accel']['Data'][:, c], nan=0.0) for c in cols]
        omega = np.sqrt(x**2 + y**2 + z**2)
        KE = 0.5 * I * omega**2
        KE_df[segment_name] = KE

    # Calculate total kinetic energy
    KE_df['total'] = (KE_df['W'] + KE_df['C'] + KE_df['AL'] + KE_df['AR'])
    # print(KE_df['total'])
    num_intervals = len(indDF[subject[1]]) - 1

    # Calculate HR means for each interval
    kePoints = [
        round(KE_df['total'].iloc[int(indDF[subject[1]][i]):int(indDF[subject[1]][i + 1])].mean(), 4)
        for i in range(num_intervals)
    ]
    kePoints = [x for x in kePoints if x == x]
    print(kePoints)
    # Energy expenditure calculations
    timeF = result[subject[0]][subject[1]]['APDM_Accel']['Data'][:, 0]
    ke_slice_start = result[subject[0]][subject[1]]['APDM_Accel']['Data'][0, 0] + indDF[subject[1]][0] / 128
    ke_slice_end = result[subject[0]][subject[1]]['APDM_Accel']['Data'][0, 0] + indDF[subject[1]][5] / 128

    # Calculate EE ground values
    VO2 = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, vo2]
    VCO2 = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, vco2]
    EE = (16.58 * VO2 + 4.15 * VCO2) / mass[0]
    EE_ground = np.zeros(np.size(EE))

    ind = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, code]
    ind = ind[:-1] - ind[1:]
    bool_ind = ind != 0.0
    indShift = np.where(bool_ind)[0]  # Last index for each phase
    indShift = np.concatenate((indShift, [len(ind)]))
    
    for i in range(len(indShift)):
        T = result[subject[0]][subject[1]]['Metabolics_System']['Data'][indShift[i], 0]
        timeM3 = T - (3 * 60)
        bool_time = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, 0] < timeM3
        threeMin = indShift[i] - np.max(np.where(bool_time)[0])

        if i == 0:
            EE_ground[0:indShift[i]] = np.mean(EE[indShift[i] - threeMin : indShift[i]])
            eePoints.append(round(np.mean(EE[indShift[i] - threeMin : indShift[i]]), 4))
        elif i == len(indShift) - 1:
            EE_ground[indShift[i - 1] :] = np.mean(EE[-threeMin:])
            eePoints.append(round(np.mean(EE[-threeMin:]), 4))
        else:
            EE_ground[indShift[i - 1] : indShift[i] + 1] = np.mean(EE[indShift[i] - threeMin : indShift[i]])
            eePoints.append(round(np.mean(EE[indShift[i] - threeMin : indShift[i]]), 4))
    
    if subject[1] == 'Incline':
        eePoints = eePoints[1:-1]
    if subject[1] != 'Incline':
        # eePoints.append(0)
        eePoints = eePoints[1:-1]
    if len(eePoints) is not len(kePoints):
        print("Error in " + subject[0] + " " + subject[1])
        continue
    print(eePoints)

    # Visualization
    lastNZ = indDF[subject[1]][indDF[subject[1]] != 0].index[-1]
    time_slice = timeF[indDF[subject[1]][0]:indDF[subject[1]][lastNZ]]
    KE_slice = KE_df['total'][indDF[subject[1]][0]:indDF[subject[1]][lastNZ]]

    ke_eeDF = pd.DataFrame({'ke': kePoints, 'ee': eePoints})
    ke_eeDF['Time'] = (indDF[subject[1]][0:len(ke_eeDF)].reset_index(drop=True))/128
    
    newRow = ke_eeDF.iloc[-1].to_dict()
    newRow["Time"] = indDF[subject[1]][len(ke_eeDF)]/128
    ke_eeDF = pd.concat([ke_eeDF, pd.DataFrame([newRow])], ignore_index=True)
    ke_eeDF['Subject'] = subject[0]
    print(ke_eeDF)
    
    fig, ax1 = plt.subplots()
    color = 'tab:blue'
    ax1.set_xlabel('Time (s)')
    ax1.set_ylabel('Kinetic Energy (W/kg)', color=color)
    ax1.plot(time_slice, KE_slice, color=color)
    ax1.tick_params(axis='y', labelcolor=color)

    x = ke_eeDF['Time']
    y = ke_eeDF['ke']
    plt.step(x, y, where='post',color='black')
    for i in range(len(x) - 1):
        plt.text(x[i] + 175, y[i] + 0.03, f'{y[i]}', ha='center', va='bottom')
        
    ax2 = ax1.twinx()
    color = 'tab:orange'
    ax2.set_ylabel('EE Ground (W/kg)', color=color)
    ax2.plot(result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, 0], EE_ground, '-', color=color)
    ax2.tick_params(axis='y', labelcolor=color)

    plt.xlabel('Time (s)')
    plt.title('Kinetic Energy vs. EE Ground')
    plt.show()
    
    if subject[1] == 'Incline':
        ke_eeDF.drop(2, inplace=True)
        df_list.append(ke_eeDF)
    else:
        df_list.append(ke_eeDF)

# %%
final_df = pd.concat(df_list, ignore_index=True)
print(final_df)

# %%
# Create a list of unique subjects
import math
from sklearn.metrics import r2_score

subjects = final_df['Subject'].unique()
final_df = final_df[final_df['ee'] != 0]

# Create the plot
plt.figure(figsize=(10, 6))

# Plot each subject with a line of best fit
for subject in subjects:
    # Filter the data for each subject
    subject_data = final_df[final_df['Subject'] == subject]
    
    # Scatter plot for HR vs EE
    plt.scatter(subject_data['ke'], subject_data['ee'])
    
    # Fit a line (best fit) for the data points
    m, b = np.polyfit(subject_data['ke'], subject_data['ee'], 1)
    y_pred = m * subject_data['ke'] + b
    plt.plot(subject_data['ke'], y_pred, label=subject)
    
    r2 = r2_score(subject_data['ee'], y_pred)
    r = math.sqrt(r2)
    print(f"R for {subject}: {r}")


# Add titles and labels
plt.xlabel('Kinetic Energy (W/kg)')
plt.ylabel('EE Ground (W/kg)')

# Show the legend
plt.legend(title='Subject')

# Show the plot
plt.show()

# %%
# 3 min average
analyzed = set()
subjectName = []
index = -1
df_list = []
df_list_R = []

for subject in result.keys():
    # Skip certain activities
    if subject[0] == "Subject02" and subject[1] in ['Backwards','Backwards2']:
        continue
    if subject[0] == "Subject05" and subject[1] in ['Cycling','Cycling2']:
        continue
    kePoints = []
    eePoints = []
    # Initialize/reset DataFrames for each subject
    KE_df = pd.DataFrame()
    KE_means_df = pd.DataFrame(columns=["Segment", "KE_Mean"])
    
    mNorm = mass[index] / 82.2
    
    if subject[0] not in analyzed:
        index += 1
    print(f"{subject[0]} {subject[1]}\n-----------")
    analyzed.add(subject[0])
    

    indDF = globals()[subject[0]].astype(int)


    # Parameters for different segments
    segments = [
        {'Name': 'W', 'I': 0.02654, 'columns': [5, 6, 7]},    # W
        {'Name': 'C', 'I': 0.33201, 'columns': [14, 15, 16]}, # C
        {'Name': 'AL', 'I': 0.06397, 'columns': [23, 24, 25]}, # AL
        {'Name': 'AR', 'I': 0.06271, 'columns': [32, 33, 34]}  # AR
    ]

    # Calculate kinetic energy for each segment
    for segment in segments:
        segment_name = segment['Name']
        I = segment['I'] * mNorm
        cols = segment['columns']
        
        # Extract and compute omega
        x, y, z = [np.nan_to_num(result[subject[0]][subject[1]]['APDM_Accel']['Data'][:, c], nan=0.0) for c in cols]
        omega = np.sqrt(x**2 + y**2 + z**2)
        KE = 0.5 * I * omega**2
        KE_df[segment_name] = KE

    # Calculate total kinetic energy
    KE_df['total'] = (KE_df['W'] + KE_df['C'] + KE_df['AL'] + KE_df['AR'])
    # print(KE_df['total'])
    num_intervals = len(indDF[subject[1]]) - 1

    # Calculate HR means for each interval
    kePoints = [
        round(KE_df['total'].iloc[int(indDF[subject[1]][i+1])-23040:int(indDF[subject[1]][i + 1])].mean(), 4)
        for i in range(num_intervals)
    ]
    kePoints = [x for x in kePoints if x == x]
    print(kePoints)
    # Energy expenditure calculations
    timeF = result[subject[0]][subject[1]]['APDM_Accel']['Data'][:, 0]
    ke_slice_start = result[subject[0]][subject[1]]['APDM_Accel']['Data'][0, 0] + indDF[subject[1]][0] / 128
    ke_slice_end = result[subject[0]][subject[1]]['APDM_Accel']['Data'][0, 0] + indDF[subject[1]][5] / 128

    # Calculate EE ground values
    VO2 = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, vo2]
    VCO2 = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, vco2]
    EE = (16.58 * VO2 + 4.15 * VCO2) / mass[0]
    EE_ground = np.zeros(np.size(EE))

    ind = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, code]
    ind = ind[:-1] - ind[1:]
    bool_ind = ind != 0.0
    indShift = np.where(bool_ind)[0]  # Last index for each phase
    indShift = np.concatenate((indShift, [len(ind)]))
    
    T_first_phase = result[subject[0]][subject[1]]['Metabolics_System']['Data'][indShift[0], 0]
    timeM3_first = T_first_phase - (3 * 60)
    bool_time_first = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, 0] < timeM3_first
    threeMin_first = indShift[0] - np.max(np.where(bool_time_first)[0])

    EE_avg_first = np.mean(EE[indShift[0] - threeMin_first:indShift[0]])
 
    for i in range(len(indShift)):
        T = result[subject[0]][subject[1]]['Metabolics_System']['Data'][indShift[i], 0]
        timeM3 = T - (3 * 60)
        bool_time = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, 0] < timeM3
        threeMin = indShift[i] - np.max(np.where(bool_time)[0])

        if i == 0:
            EE_ground[0:indShift[i]] = np.mean(EE[indShift[i] - threeMin : indShift[i]]) - EE_avg_first
            eePoints.append(round(np.mean(EE[indShift[i] - threeMin : indShift[i]] - EE_avg_first), 4))
        elif i == len(indShift) - 1:
            EE_ground[indShift[i - 1] :] = np.mean(EE[-threeMin:]) - EE_avg_first
            eePoints.append(round(np.mean(EE[-threeMin:] - EE_avg_first), 4))
        else:
            EE_ground[indShift[i - 1] : indShift[i] + 1] = np.mean(EE[indShift[i] - threeMin : indShift[i]])- EE_avg_first
            eePoints.append(round(np.mean(EE[indShift[i] - threeMin : indShift[i]]- EE_avg_first), 4))
    
    if subject[1] == 'Incline':
        eePoints = eePoints[1:-1]
    if subject[1] != 'Incline':
        # eePoints.append(0)
        eePoints = eePoints[1:-1]
    if len(eePoints) is not len(kePoints):
        print("Error in " + subject[0] + " " + subject[1])
        continue
    print(eePoints)

    # Visualization
    lastNZ = indDF[subject[1]][indDF[subject[1]] != 0].index[-1]
    time_slice = timeF[indDF[subject[1]][0]:indDF[subject[1]][lastNZ]]
    KE_slice = KE_df['total'][indDF[subject[1]][0]:indDF[subject[1]][lastNZ]]

    ke_eeDF = pd.DataFrame({'ke': kePoints, 'ee': eePoints})
    ke_eeDF['Time'] = (indDF[subject[1]][0:len(ke_eeDF)].reset_index(drop=True))/128
    
        
    newRow = ke_eeDF.iloc[-1].to_dict()
    newRow["Time"] = indDF[subject[1]][len(ke_eeDF)]/128
    ke_eeDF = pd.concat([ke_eeDF, pd.DataFrame([newRow])], ignore_index=True)
    ke_eeDF['Subject'] = subject[0]
    print(ke_eeDF)
    
    fig, ax1 = plt.subplots()
    color = 'tab:blue'
    ax1.set_xlabel('Time (s)')
    ax1.set_ylabel('Kinetic Energy (W/kg)', color=color)
    ax1.plot(time_slice, KE_slice, color=color)
    ax1.tick_params(axis='y', labelcolor=color)

    x = ke_eeDF['Time']
    y = ke_eeDF['ke']
    plt.step(x, y, where='post',color='black')
    for i in range(len(x) - 1):
        plt.text(x[i] + 175, y[i] + 0.03, f'{y[i]}', ha='center', va='bottom')
        
    ax2 = ax1.twinx()
    color = 'tab:orange'
    ax2.set_ylabel('EE Ground (W/kg)', color=color)
    ax2.plot(result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, 0], EE_ground, '-', color=color)
    ax2.tick_params(axis='y', labelcolor=color)

    plt.xlabel('Time (s)')
    plt.title('Kinetic Energy vs. EE Ground')
    plt.show()
    
    if subject[1] == 'Incline':
        ke_eeDF.drop(2, inplace=True)
        df_list.append(ke_eeDF)
    else:
        df_list.append(ke_eeDF)
        
    df_list_R.append(ke_eeDF[:-1])

# %%
# 5x 1-minute average KE per interval
analyzed = set()
subjectName = []
index = -1
df_list = []
df_list_R = []

for subject in result.keys():
    # Skip certain activities
    if subject[0] == "Subject02" and subject[1] in ['Backwards','Backwards2']:
        continue
    if subject[0] == "Subject05" and subject[1] in ['Cycling','Cycling2']:
        continue
    kePoints = []
    eePoints = []
    # Initialize/reset DataFrames for each subject
    KE_df = pd.DataFrame()
    KE_means_df = pd.DataFrame(columns=["Segment", "KE_Mean"])
    
    mNorm = mass[index] / 82.2
    
    if subject[0] not in analyzed:
        index += 1
    print(f"{subject[0]} {subject[1]}\n-----------")
    analyzed.add(subject[0])
    
    indDF = globals()[subject[0]].astype(int)

    # Parameters for different segments
    segments = [
        {'Name': 'W', 'I': 0.02654, 'columns': [5, 6, 7]},    # W
        {'Name': 'C', 'I': 0.33201, 'columns': [14, 15, 16]}, # C
        {'Name': 'AL', 'I': 0.06397, 'columns': [23, 24, 25]}, # AL
        {'Name': 'AR', 'I': 0.06271, 'columns': [32, 33, 34]}  # AR
    ]

    # Calculate kinetic energy for each segment
    for segment in segments:
        segment_name = segment['Name']
        I = segment['I'] * mNorm
        cols = segment['columns']
        
        # Extract and compute omega
        x, y, z = [np.nan_to_num(result[subject[0]][subject[1]]['APDM_Accel']['Data'][:, c], nan=0.0) for c in cols]
        omega = np.sqrt(x**2 + y**2 + z**2)
        KE = 0.5 * I * omega**2
        KE_df[segment_name] = KE

    # Calculate total kinetic energy
    KE_df['total'] = (KE_df['W'] + KE_df['C'] + KE_df['AL'] + KE_df['AR'])
    num_intervals = len(indDF[subject[1]]) - 1

    for i in range(num_intervals):
        interval_start = int(indDF[subject[1]][i])
        interval_end = int(indDF[subject[1]][i + 1])
        samples_per_minute = 60 * 128

        for minute in range(5):
            bin_start = interval_start + minute * samples_per_minute
            bin_end = bin_start + samples_per_minute

            if bin_end <= interval_end:
                mean_val = round(KE_df['total'].iloc[bin_start:bin_end].mean(), 4)
                kePoints.append(mean_val)
            else:
                break

    kePoints = [x for x in kePoints if x == x] # Remove NaN
    print(kePoints)

    # Energy expenditure calculations
    timeF = result[subject[0]][subject[1]]['APDM_Accel']['Data'][:, 0]
    ke_slice_start = result[subject[0]][subject[1]]['APDM_Accel']['Data'][0, 0] + indDF[subject[1]][0] / 128
    ke_slice_end = result[subject[0]][subject[1]]['APDM_Accel']['Data'][0, 0] + indDF[subject[1]][5] / 128

    VO2 = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, vo2]
    VCO2 = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, vco2]
    EE = (16.58 * VO2 + 4.15 * VCO2) / mass[0]
    EE_ground = np.zeros(np.size(EE))

    ind = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, code]
    ind = ind[:-1] - ind[1:]
    bool_ind = ind != 0.0
    indShift = np.where(bool_ind)[0]
    indShift = np.concatenate((indShift, [len(ind)]))

    T_first_phase = result[subject[0]][subject[1]]['Metabolics_System']['Data'][indShift[0], 0]
    timeM3_first = T_first_phase - (3 * 60)
    bool_time_first = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, 0] < timeM3_first
    threeMin_first = indShift[0] - np.max(np.where(bool_time_first)[0])

    EE_avg_first = np.mean(EE[indShift[0] - threeMin_first:indShift[0]])

    for i in range(len(indShift)):
        T = result[subject[0]][subject[1]]['Metabolics_System']['Data'][indShift[i], 0]
        timeM3 = T - (3 * 60)
        bool_time = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, 0] < timeM3
        threeMin = indShift[i] - np.max(np.where(bool_time)[0])

        if i == 0:
            EE_ground[0:indShift[i]] = np.mean(EE[indShift[i] - threeMin:indShift[i]]) - EE_avg_first
            eePoints.append(round(np.mean(EE[indShift[i] - threeMin:indShift[i]] - EE_avg_first), 4))
        elif i == len(indShift) - 1:
            EE_ground[indShift[i - 1]:] = np.mean(EE[-threeMin:]) - EE_avg_first
            eePoints.append(round(np.mean(EE[-threeMin:] - EE_avg_first), 4))
        else:
            EE_ground[indShift[i - 1]:indShift[i] + 1] = np.mean(EE[indShift[i] - threeMin:indShift[i]]) - EE_avg_first
            eePoints.append(round(np.mean(EE[indShift[i] - threeMin:indShift[i]] - EE_avg_first), 4))

    if subject[1] == 'Incline':
        eePoints = eePoints[1:-1]
    if subject[1] != 'Incline':
        eePoints = eePoints[1:-1]

    if len(eePoints) * 5 != len(kePoints):  
        print("Error in " + subject[0] + " " + subject[1])
        continue
    print(eePoints)

    # For plot
    lastNZ = indDF[subject[1]][indDF[subject[1]] != 0].index[-1]
    time_slice = timeF[indDF[subject[1]][0]:indDF[subject[1]][lastNZ]]
    KE_slice = KE_df['total'][indDF[subject[1]][0]:indDF[subject[1]][lastNZ]]

    ke_eeDF = pd.DataFrame({'ke': kePoints})

    ke_eeDF['ee'] = np.repeat(eePoints, 5)[:len(ke_eeDF)]
    ke_eeDF['Time'] = [360 + 60 * i + 60 * ((i) // 5) for i in range(len(kePoints))]

    newRow = ke_eeDF.iloc[-1].to_dict()
    newRow["Time"] = indDF[subject[1]][len(ke_eeDF) / 5] / 128
    ke_eeDF = pd.concat([ke_eeDF, pd.DataFrame([newRow])], ignore_index=True)
    ke_eeDF['Subject'] = subject[0]
    ke_eeDF['Activity'] = subject[1]
    print(ke_eeDF)

    fig, ax1 = plt.subplots()
    color = 'tab:blue'
    ax1.set_xlabel('Time (s)')
    ax1.set_ylabel('Kinetic Energy (W/kg)', color=color)
    ax1.plot(time_slice, KE_slice, color=color)
    ax1.tick_params(axis='y', labelcolor=color)

    x = ke_eeDF['Time']
    y = ke_eeDF['ke']
    plt.step(x, y, where='post', color='black')
    # for i in range(len(x) - 1):
    #     plt.text(x[i] + 175, y[i] + 0.03, f'{y[i]}', ha='center', va='bottom')

    ax2 = ax1.twinx()
    color = 'tab:orange'
    ax2.set_ylabel('EE Ground (W/kg)', color=color)
    ax2.plot(result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, 0], EE_ground, '-', color=color)
    ax2.tick_params(axis='y', labelcolor=color)

    plt.xlabel('Time (s)')
    plt.title('Kinetic Energy vs. EE Ground')
    plt.show()

    if subject[1] == 'Incline':
        # ke_eeDF.drop(2, inplace=True)
        df_list.append(ke_eeDF)
    else:
        df_list.append(ke_eeDF)

    df_list_R.append(ke_eeDF[:-1])

# %%
pd.set_option('display.max_rows', 2000)
final_df_r = pd.concat(df_list_R, ignore_index=True)
print(final_df_r)

# %%
pd.set_option('display.max_rows', 2000)
final_df = pd.concat(df_list, ignore_index=True)
print(final_df)

# %%
# Create a list of unique subjects
import math
from sklearn.metrics import r2_score

subjects = final_df['Subject'].unique()
final_df = final_df[final_df['ee'] != 0]

# Create the plot
plt.figure(figsize=(10, 6))

# Plot each subject with a line of best fit
for subject in subjects:
    # Filter the data for each subject
    subject_data = final_df[final_df['Subject'] == subject]
    
    # Scatter plot for HR vs EE
    plt.scatter(subject_data['ke'], subject_data['ee'])
    
    # Fit a line (best fit) for the data points
    m, b = np.polyfit(subject_data['ke'], subject_data['ee'], 1)
    y_pred = m * subject_data['ke'] + b
    plt.plot(subject_data['ke'], y_pred, label=subject)
    
    r2 = r2_score(subject_data['ee'], y_pred)
    r = math.sqrt(r2)
    print(f"R for {subject}: {r}")


# Add titles and labels
plt.xlabel('Kinetic Energy (W/kg)')
plt.ylabel('EE Ground (W/kg)')

# Show the legend
plt.legend(title='Subject')

# Show the plot
plt.show()

# %%
# 20x 15-second average KE per interval
analyzed = set()
subjectName = []
index = -1
df_list = []
df_list_R = []

for subject in result.keys():
    # Skip certain activities
    if subject[0] == "Subject02" and subject[1] in ['Backwards','Backwards2']:
        continue
    if subject[0] == "Subject05" and subject[1] in ['Cycling','Cycling2']:
        continue
    kePoints = []
    eePoints = []
    # Initialize/reset DataFrames for each subject
    KE_df = pd.DataFrame()
    KE_means_df = pd.DataFrame(columns=["Segment", "KE_Mean"])
    
    mNorm = mass[index] / 82.2
    
    if subject[0] not in analyzed:
        index += 1
    print(f"{subject[0]} {subject[1]}\n-----------")
    analyzed.add(subject[0])
    
    indDF = globals()[subject[0]].astype(int)

    # Parameters for different segments
    segments = [
        {'Name': 'W',  'I': 0.02654, 'mass': 0, 'dist': 0, 'columns': [5, 6, 7]},     # W
        {'Name': 'C',  'I': 0.33201, 'mass': 0, 'dist': 0, 'columns': [14, 15, 16]},  # C
        {'Name': 'AL', 'I': 0.06397, 'mass': 3.525, 'dist': 0.6154, 'columns': [23, 24, 25]},  # AL
        {'Name': 'AR', 'I': 0.06271, 'mass': 3.525, 'dist': 0.6154, 'columns': [32, 33, 34]}   # AR
    ]

    # Calculate kinetic energy for each segment
    for segment in segments:
        segment_name = segment['Name']
        I = segment['I'] * mNorm
        cols = segment['columns']
        m = segment['mass']
        r = segment['dist']
        
        # Compute omega
        x, y, z = [np.nan_to_num(result[subject[0]][subject[1]]['APDM_Accel']['Data'][:, c], nan=0.0) for c in cols]
        omega = np.sqrt(x**2 + y**2 + z**2)
        KE = 0.5 * (I + (m*(0.5*r)**2)) * omega**2
        KE_df[segment_name] = KE

    # Calculate total kinetic energy
    KE_df['total'] = (KE_df['W'] + KE_df['C'] + KE_df['AL'] + KE_df['AR'])
    num_intervals = len(indDF[subject[1]]) - 1

    samples_per_fifteen = 15 * 128   # 1920 samples in 15 seconds
    bins_per_interval = 20           # 5 minutes × 4 bins/min

    for i in range(num_intervals):
        interval_start = int(indDF[subject[1]][i])
        interval_end = int(indDF[subject[1]][i + 1])

        for b in range(bins_per_interval):
            bin_start = interval_start + b * samples_per_fifteen
            bin_end = bin_start + samples_per_fifteen

            if bin_end <= interval_end:
                mean_val = round(KE_df['total'].iloc[bin_start:bin_end].mean(), 4)
                kePoints.append(mean_val)
            else:
                break

    kePoints = [x for x in kePoints if x == x] # Remove NaN
    print(kePoints)

    # Energy expenditure calculations
    timeF = result[subject[0]][subject[1]]['APDM_Accel']['Data'][:, 0]
    ke_slice_start = result[subject[0]][subject[1]]['APDM_Accel']['Data'][0, 0] + indDF[subject[1]][0] / 128
    ke_slice_end = result[subject[0]][subject[1]]['APDM_Accel']['Data'][0, 0] + indDF[subject[1]][5] / 128

    VO2 = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, vo2]
    VCO2 = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, vco2]
    EE = (16.58 * VO2 + 4.15 * VCO2) / mass[0]
    EE_ground = np.zeros(np.size(EE))

    ind = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, code]
    ind = ind[:-1] - ind[1:]
    bool_ind = ind != 0.0
    indShift = np.where(bool_ind)[0]
    indShift = np.concatenate((indShift, [len(ind)]))

    T_first_phase = result[subject[0]][subject[1]]['Metabolics_System']['Data'][indShift[0], 0]
    timeM3_first = T_first_phase - (3 * 60)
    bool_time_first = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, 0] < timeM3_first
    threeMin_first = indShift[0] - np.max(np.where(bool_time_first)[0])

    EE_avg_first = np.mean(EE[indShift[0] - threeMin_first:indShift[0]])

    for i in range(len(indShift)):
        T = result[subject[0]][subject[1]]['Metabolics_System']['Data'][indShift[i], 0]
        timeM3 = T - (3 * 60)
        bool_time = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, 0] < timeM3
        threeMin = indShift[i] - np.max(np.where(bool_time)[0])

        if i == 0:
            EE_ground[0:indShift[i]] = np.mean(EE[indShift[i] - threeMin:indShift[i]]) - EE_avg_first
            eePoints.append(round(np.mean(EE[indShift[i] - threeMin:indShift[i]] - EE_avg_first), 4))
        elif i == len(indShift) - 1:
            EE_ground[indShift[i - 1]:] = np.mean(EE[-threeMin:]) - EE_avg_first
            eePoints.append(round(np.mean(EE[-threeMin:] - EE_avg_first), 4))
        else:
            EE_ground[indShift[i - 1]:indShift[i] + 1] = np.mean(EE[indShift[i] - threeMin:indShift[i]]) - EE_avg_first
            eePoints.append(round(np.mean(EE[indShift[i] - threeMin:indShift[i]] - EE_avg_first), 4))

    if subject[1] == 'Incline':
        eePoints = eePoints[1:-1]
    if subject[1] != 'Incline':
        eePoints = eePoints[1:-1]

    # Adjust check: 20 bins per EE point now
    if len(eePoints) * 20 != len(kePoints):  
        print("Error in " + subject[0] + " " + subject[1])
        continue
    print(eePoints)

    # For plot
    lastNZ = indDF[subject[1]][indDF[subject[1]] != 0].index[-1]
    time_slice = timeF[indDF[subject[1]][0]:indDF[subject[1]][lastNZ]]
    KE_slice = KE_df['total'][indDF[subject[1]][0]:indDF[subject[1]][lastNZ]]

    ke_eeDF = pd.DataFrame({'ke': kePoints})

    # Repeat EE 20 times per interval
    ke_eeDF['ee'] = np.repeat(eePoints, 20)[:len(ke_eeDF)]

    # Time axis: 15s steps instead of 60s
    ke_eeDF['Time'] = [360 + 15 * i + 60 * ((i) // 20) for i in range(len(kePoints))]

    newRow = ke_eeDF.iloc[-1].to_dict()
    newRow["Time"] = indDF[subject[1]][len(ke_eeDF) // 20] / 128
    ke_eeDF = pd.concat([ke_eeDF, pd.DataFrame([newRow])], ignore_index=True)
    ke_eeDF['Subject'] = subject[0]
    ke_eeDF['Activity'] = subject[1]
    print(ke_eeDF)

    fig, ax1 = plt.subplots()
    color = 'tab:blue'
    ax1.set_xlabel('Time (s)')
    ax1.set_ylabel('Kinetic Energy (W/kg)', color=color)
    ax1.plot(time_slice, KE_slice, color=color)
    ax1.tick_params(axis='y', labelcolor=color)

    x = ke_eeDF['Time']
    y = ke_eeDF['ke']
    plt.step(x, y, where='post', color='black')

    ax2 = ax1.twinx()
    color = 'tab:orange'
    ax2.set_ylabel('EE Ground (W/kg)', color=color)
    ax2.plot(result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, 0], EE_ground, '-', color=color)
    ax2.tick_params(axis='y', labelcolor=color)

    plt.xlabel('Time (s)')
    plt.title('Kinetic Energy vs. EE Ground')
    plt.show()

    if subject[1] == 'Incline':
        df_list.append(ke_eeDF)
    else:
        df_list.append(ke_eeDF)

    df_list_R.append(ke_eeDF[:-1])
# Out:
# Subject01 Backwards
# -----------
# [0.8074, 0.9266, 0.9052, 0.9123, 0.8525, 0.8928, 0.8397, 0.8608, 0.8898, 0.8786, 0.8772, 0.8512, 0.8026, 0.7973, 0.8693, 0.902, 0.9184, 0.8857, 0.8871, 0.8334, 1.7916, 1.7527, 1.8168, 1.8648, 1.8055, 1.8374, 1.8202, 1.783, 1.8393, 1.7429, 1.77, 1.827, 1.7338, 1.8148, 1.8033, 1.7866, 1.7077, 1.7049, 1.7412, 1.7535, 2.6549, 2.6127, 2.7408, 2.6545, 2.7541, 2.7877, 2.7644, 2.7528, 2.7875, 2.8265, 2.8375, 2.7266, 2.7541, 2.8069, 2.8006, 2.8821, 2.7455, 2.7524, 2.6771, 2.8561]
# [1.3861, 2.3818, 3.4005]
#         ke      ee         Time    Subject   Activity
# 0   0.8074  1.3861   360.000000  Subject01  Backwards
# 1   0.9266  1.3861   375.000000  Subject01  Backwards
# 2   0.9052  1.3861   390.000000  Subject01  Backwards
# 3   0.9123  1.3861   405.000000  Subject01  Backwards
# 4   0.8525  1.3861   420.000000  Subject01  Backwards
# 5   0.8928  1.3861   435.000000  Subject01  Backwards
# 6   0.8397  1.3861   450.000000  Subject01  Backwards
# 7   0.8608  1.3861   465.000000  Subject01  Backwards
# 8   0.8898  1.3861   480.000000  Subject01  Backwards
# 9   0.8786  1.3861   495.000000  Subject01  Backwards
# 10  0.8772  1.3861   510.000000  Subject01  Backwards
# 11  0.8512  1.3861   525.000000  Subject01  Backwards
# 12  0.8026  1.3861   540.000000  Subject01  Backwards
# 13  0.7973  1.3861   555.000000  Subject01  Backwards
# 14  0.8693  1.3861   570.000000  Subject01  Backwards
# 15  0.9020  1.3861   585.000000  Subject01  Backwards
# 16  0.9184  1.3861   600.000000  Subject01  Backwards
# 17  0.8857  1.3861   615.000000  Subject01  Backwards
# 18  0.8871  1.3861   630.000000  Subject01  Backwards
# 19  0.8334  1.3861   645.000000  Subject01  Backwards
# 20  1.7916  2.3818   720.000000  Subject01  Backwards
# 21  1.7527  2.3818   735.000000  Subject01  Backwards
# 22  1.8168  2.3818   750.000000  Subject01  Backwards
# 23  1.8648  2.3818   765.000000  Subject01  Backwards
# 24  1.8055  2.3818   780.000000  Subject01  Backwards
# 25  1.8374  2.3818   795.000000  Subject01  Backwards
# 26  1.8202  2.3818   810.000000  Subject01  Backwards
# 27  1.7830  2.3818   825.000000  Subject01  Backwards
# 28  1.8393  2.3818   840.000000  Subject01  Backwards
# 29  1.7429  2.3818   855.000000  Subject01  Backwards
# 30  1.7700  2.3818   870.000000  Subject01  Backwards
# 31  1.8270  2.3818   885.000000  Subject01  Backwards
# 32  1.7338  2.3818   900.000000  Subject01  Backwards
# 33  1.8148  2.3818   915.000000  Subject01  Backwards
# 34  1.8033  2.3818   930.000000  Subject01  Backwards
# 35  1.7866  2.3818   945.000000  Subject01  Backwards
# 36  1.7077  2.3818   960.000000  Subject01  Backwards
# 37  1.7049  2.3818   975.000000  Subject01  Backwards
# 38  1.7412  2.3818   990.000000  Subject01  Backwards
# 39  1.7535  2.3818  1005.000000  Subject01  Backwards
# 40  2.6549  3.4005  1080.000000  Subject01  Backwards
# 41  2.6127  3.4005  1095.000000  Subject01  Backwards
# 42  2.7408  3.4005  1110.000000  Subject01  Backwards
# 43  2.6545  3.4005  1125.000000  Subject01  Backwards
# 44  2.7541  3.4005  1140.000000  Subject01  Backwards
# 45  2.7877  3.4005  1155.000000  Subject01  Backwards
# 46  2.7644  3.4005  1170.000000  Subject01  Backwards
# 47  2.7528  3.4005  1185.000000  Subject01  Backwards
# 48  2.7875  3.4005  1200.000000  Subject01  Backwards
# 49  2.8265  3.4005  1215.000000  Subject01  Backwards
# 50  2.8375  3.4005  1230.000000  Subject01  Backwards
# 51  2.7266  3.4005  1245.000000  Subject01  Backwards
# 52  2.7541  3.4005  1260.000000  Subject01  Backwards
# 53  2.8069  3.4005  1275.000000  Subject01  Backwards
# 54  2.8006  3.4005  1290.000000  Subject01  Backwards
# 55  2.8821  3.4005  1305.000000  Subject01  Backwards
# 56  2.7455  3.4005  1320.000000  Subject01  Backwards
# 57  2.7524  3.4005  1335.000000  Subject01  Backwards
# 58  2.6771  3.4005  1350.000000  Subject01  Backwards
# 59  2.8561  3.4005  1365.000000  Subject01  Backwards
# 60  2.8561  3.4005  1440.046875  Subject01  Backwards
# Subject01 Cycling
# -----------
# [3.1204, 3.7002, 3.7002, 3.7553, 3.7167, 3.6829, 3.6364, 3.602, 3.5419, 3.6915, 3.6929, 3.6686, 3.7067, 3.7221, 3.7342, 3.6559, 3.6553, 3.7321, 3.7519, 3.6903, 1.3945, 1.3385, 1.3429, 1.2836, 1.3254, 1.3177, 1.3389, 1.3704, 1.3532, 1.3301, 1.3663, 1.334, 1.3521, 1.2982, 1.3092, 1.4078, 1.3275, 1.3476, 1.3756, 1.3265, 0.9336, 0.0525, 0.0929, 0.0185, 0.0839, 0.037, 0.0463, 0.0695, 0.0504, 0.0343, 0.0217, 0.0443, 0.0631, 0.0154, 0.0153, 0.0112, 0.0222, 0.0073, 0.0176, 0.0078, 0.8442, 1.0054, 1.0471, 1.0263, 1.0239, 1.0205, 1.009, 0.9749, 0.9733, 0.9376, 0.9464, 0.9845, 1.0341, 0.9776, 1.0118, 1.0479, 0.9935, 1.0456, 1.1085, 1.0626, 2.6325, 2.7842, 2.8347, 2.9034, 2.8614, 2.8359, 2.8814, 2.8659, 2.8154, 2.8524, 2.8615, 2.8594, 2.7818, 2.8473, 2.8601, 2.8873, 2.8927, 2.8422, 2.7631, 2.776]
# [4.3915, 2.1477, -0.0283, 3.406, 7.3179]
#          ke      ee         Time    Subject Activity
# 0    3.1204  4.3915   360.000000  Subject01  Incline
# 1    3.7002  4.3915   375.000000  Subject01  Incline
# 2    3.7002  4.3915   390.000000  Subject01  Incline
# 3    3.7553  4.3915   405.000000  Subject01  Incline
# 4    3.7167  4.3915   420.000000  Subject01  Incline
# 5    3.6829  4.3915   435.000000  Subject01  Incline
# 6    3.6364  4.3915   450.000000  Subject01  Incline
# 7    3.6020  4.3915   465.000000  Subject01  Incline
# 8    3.5419  4.3915   480.000000  Subject01  Incline
# 9    3.6915  4.3915   495.000000  Subject01  Incline
# 10   3.6929  4.3915   510.000000  Subject01  Incline
# 11   3.6686  4.3915   525.000000  Subject01  Incline
# 12   3.7067  4.3915   540.000000  Subject01  Incline
# 13   3.7221  4.3915   555.000000  Subject01  Incline
# 14   3.7342  4.3915   570.000000  Subject01  Incline
# 15   3.6559  4.3915   585.000000  Subject01  Incline
# 16   3.6553  4.3915   600.000000  Subject01  Incline
# 17   3.7321  4.3915   615.000000  Subject01  Incline
# 18   3.7519  4.3915   630.000000  Subject01  Incline
# 19   3.6903  4.3915   645.000000  Subject01  Incline
# 20   1.3945  2.1477   720.000000  Subject01  Incline
# 21   1.3385  2.1477   735.000000  Subject01  Incline
# 22   1.3429  2.1477   750.000000  Subject01  Incline
# 23   1.2836  2.1477   765.000000  Subject01  Incline
# 24   1.3254  2.1477   780.000000  Subject01  Incline
# 25   1.3177  2.1477   795.000000  Subject01  Incline
# 26   1.3389  2.1477   810.000000  Subject01  Incline
# 27   1.3704  2.1477   825.000000  Subject01  Incline
# 28   1.3532  2.1477   840.000000  Subject01  Incline
# 29   1.3301  2.1477   855.000000  Subject01  Incline
# 30   1.3663  2.1477   870.000000  Subject01  Incline
# 31   1.3340  2.1477   885.000000  Subject01  Incline
# 32   1.3521  2.1477   900.000000  Subject01  Incline
# 33   1.2982  2.1477   915.000000  Subject01  Incline
# 34   1.3092  2.1477   930.000000  Subject01  Incline
# 35   1.4078  2.1477   945.000000  Subject01  Incline
# 36   1.3275  2.1477   960.000000  Subject01  Incline
# 37   1.3476  2.1477   975.000000  Subject01  Incline
# 90   2.8615  7.3179  1950.000000  Subject01  Incline
# 91   2.8594  7.3179  1965.000000  Subject01  Incline
# 92   2.7818  7.3179  1980.000000  Subject01  Incline
# 93   2.8473  7.3179  1995.000000  Subject01  Incline
# 94   2.8601  7.3179  2010.000000  Subject01  Incline
# 95   2.8873  7.3179  2025.000000  Subject01  Incline
# 96   2.8927  7.3179  2040.000000  Subject01  Incline
# 97   2.8422  7.3179  2055.000000  Subject01  Incline
# 98   2.7631  7.3179  2070.000000  Subject01  Incline
# 99   2.7760  7.3179  2085.000000  Subject01  Incline
# 100  2.7760  7.3179  2160.070312  Subject01  Incline
# Subject01 Running
# -----------
# [3.5246, 4.0728, 4.0743, 4.1397, 4.1851, 4.1156, 4.1362, 4.1261, 4.0707, 4.1195, 4.1284, 4.0435, 4.06, 4.1021, 4.0833, 4.1695, 4.1256, 4.1073, 4.1685, 4.0999, 6.5897, 7.9408, 8.086, 7.9612, 8.0552, 8.0991, 8.0269, 7.9239, 7.9193, 8.0328, 8.0619, 8.0024, 8.1547, 8.1981, 8.117, 8.0497, 8.118, 8.1159, 8.0815, 8.0823, 10.8889, 10.9001, 10.8197, 10.9275, 10.7721, 10.6718, 10.5405, 10.938, 10.9413, 10.7504, 10.6489, 10.6463, 10.9142, 10.5543, 10.4163, 10.5375, 10.6604, 10.6139, 10.6576, 10.7973]
# [2.1805, 7.4136, 9.487]
#          ke      ee         Time    Subject Activity
# 0    3.5246  2.1805   360.000000  Subject01  Running
# 1    4.0728  2.1805   375.000000  Subject01  Running
# 2    4.0743  2.1805   390.000000  Subject01  Running
# 3    4.1397  2.1805   405.000000  Subject01  Running
# 4    4.1851  2.1805   420.000000  Subject01  Running
# 5    4.1156  2.1805   435.000000  Subject01  Running
# 6    4.1362  2.1805   450.000000  Subject01  Running
# 7    4.1261  2.1805   465.000000  Subject01  Running
# 8    4.0707  2.1805   480.000000  Subject01  Running
# 9    4.1195  2.1805   495.000000  Subject01  Running
# 10   4.1284  2.1805   510.000000  Subject01  Running
# 11   4.0435  2.1805   525.000000  Subject01  Running
# 12   4.0600  2.1805   540.000000  Subject01  Running
# 13   4.1021  2.1805   555.000000  Subject01  Running
# 14   4.0833  2.1805   570.000000  Subject01  Running
# 15   4.1695  2.1805   585.000000  Subject01  Running
# 16   4.1256  2.1805   600.000000  Subject01  Running
# 17   4.1073  2.1805   615.000000  Subject01  Running
# 18   4.1685  2.1805   630.000000  Subject01  Running
# 19   4.0999  2.1805   645.000000  Subject01  Running
# 20   6.5897  7.4136   720.000000  Subject01  Running
# 21   7.9408  7.4136   735.000000  Subject01  Running
# 22   8.0860  7.4136   750.000000  Subject01  Running
# 23   7.9612  7.4136   765.000000  Subject01  Running
# 24   8.0552  7.4136   780.000000  Subject01  Running
# 25   8.0991  7.4136   795.000000  Subject01  Running
# 26   8.0269  7.4136   810.000000  Subject01  Running
# 27   7.9239  7.4136   825.000000  Subject01  Running
# 28   7.9193  7.4136   840.000000  Subject01  Running
# 29   8.0328  7.4136   855.000000  Subject01  Running
# 30   8.0619  7.4136   870.000000  Subject01  Running
# 31   8.0024  7.4136   885.000000  Subject01  Running
# 32   8.1547  7.4136   900.000000  Subject01  Running
# 33   8.1981  7.4136   915.000000  Subject01  Running
# 34   8.1170  7.4136   930.000000  Subject01  Running
# 35   8.0497  7.4136   945.000000  Subject01  Running
# 36   8.1180  7.4136   960.000000  Subject01  Running
# 37   8.1159  7.4136   975.000000  Subject01  Running
# 38   8.0815  7.4136   990.000000  Subject01  Running
# 39   8.0823  7.4136  1005.000000  Subject01  Running
# 40  10.8889  9.4870  1080.000000  Subject01  Running
# 41  10.9001  9.4870  1095.000000  Subject01  Running
# 42  10.8197  9.4870  1110.000000  Subject01  Running
# 43  10.9275  9.4870  1125.000000  Subject01  Running
# 44  10.7721  9.4870  1140.000000  Subject01  Running
# 45  10.6718  9.4870  1155.000000  Subject01  Running
# 46  10.5405  9.4870  1170.000000  Subject01  Running
# 47  10.9380  9.4870  1185.000000  Subject01  Running
# 48  10.9413  9.4870  1200.000000  Subject01  Running
# 49  10.7504  9.4870  1215.000000  Subject01  Running
# 50  10.6489  9.4870  1230.000000  Subject01  Running
# 51  10.6463  9.4870  1245.000000  Subject01  Running
# 52  10.9142  9.4870  1260.000000  Subject01  Running
# 53  10.5543  9.4870  1275.000000  Subject01  Running
# 54  10.4163  9.4870  1290.000000  Subject01  Running
# 55  10.5375  9.4870  1305.000000  Subject01  Running
# 56  10.6604  9.4870  1320.000000  Subject01  Running
# 57  10.6139  9.4870  1335.000000  Subject01  Running
# 58  10.6576  9.4870  1350.000000  Subject01  Running
# 59  10.7973  9.4870  1365.000000  Subject01  Running
# 60  10.7973  9.4870  1440.046875  Subject01  Running
# Subject01 Walking
# -----------
# [2.4568, 2.7429, 2.7486, 2.825, 2.8247, 2.793, 2.7968, 2.8415, 2.8054, 2.8097, 2.8191, 2.7842, 2.793, 2.9029, 2.8537, 2.8584, 2.8954, 2.8049, 2.8552, 2.8456, 3.53, 3.9423, 4.0548, 4.0486, 4.0497, 4.0112, 4.1419, 4.0688, 4.0919, 4.1111, 4.0982, 4.1127, 4.202, 4.1629, 4.1813, 4.1118, 4.1422, 4.1468, 4.1354, 4.0775, 1.5108, 1.4886, 1.5083, 1.4702, 1.5076, 1.4829, 1.5043, 1.5169, 1.5046, 1.5526, 1.4769, 1.4194, 1.4857, 1.4362, 1.457, 1.4608, 1.4637, 1.4933, 1.4407, 1.5342]
# [1.8304, 2.2464, 0.9629]
#         ke      ee         Time    Subject Activity
# 0   2.4568  1.8304   360.000000  Subject01  Walking
# 1   2.7429  1.8304   375.000000  Subject01  Walking
# 2   2.7486  1.8304   390.000000  Subject01  Walking
# 3   2.8250  1.8304   405.000000  Subject01  Walking
# 4   2.8247  1.8304   420.000000  Subject01  Walking
# 5   2.7930  1.8304   435.000000  Subject01  Walking
# 6   2.7968  1.8304   450.000000  Subject01  Walking
# 7   2.8415  1.8304   465.000000  Subject01  Walking
# 8   2.8054  1.8304   480.000000  Subject01  Walking
# 9   2.8097  1.8304   495.000000  Subject01  Walking
# 98   1.6672  4.4280  2070.000000  Subject10  Incline
# 99   1.7430  4.4280  2085.000000  Subject10  Incline
# 100  1.7430  4.4280  2160.070312  Subject10  Incline
# Subject10 Running
# -----------
# [4.1119, 5.6232, 5.7935, 5.6232, 5.7635, 5.7009, 5.6708, 5.8005, 5.8333, 5.9389, 5.775, 5.8362, 5.7818, 5.7818, 5.6537, 5.7481, 5.8359, 5.7456, 5.9285, 5.8701]
# [2.5287]
#         ke      ee        Time    Subject Activity
# 0   4.1119  2.5287  360.000000  Subject10  Running
# 1   5.6232  2.5287  375.000000  Subject10  Running
# 2   5.7935  2.5287  390.000000  Subject10  Running
# 3   5.6232  2.5287  405.000000  Subject10  Running
# 4   5.7635  2.5287  420.000000  Subject10  Running
# 5   5.7009  2.5287  435.000000  Subject10  Running
# 6   5.6708  2.5287  450.000000  Subject10  Running
# 7   5.8005  2.5287  465.000000  Subject10  Running
# 8   5.8333  2.5287  480.000000  Subject10  Running
# 9   5.9389  2.5287  495.000000  Subject10  Running
# 10  5.7750  2.5287  510.000000  Subject10  Running
# 11  5.8362  2.5287  525.000000  Subject10  Running
# 12  5.7818  2.5287  540.000000  Subject10  Running
# 13  5.7818  2.5287  555.000000  Subject10  Running
# 14  5.6537  2.5287  570.000000  Subject10  Running
# 15  5.7481  2.5287  585.000000  Subject10  Running
# 16  5.8359  2.5287  600.000000  Subject10  Running
# 17  5.7456  2.5287  615.000000  Subject10  Running
# 18  5.9285  2.5287  630.000000  Subject10  Running
# 19  5.8701  2.5287  645.000000  Subject10  Running
# 20  5.8701  2.5287  720.015625  Subject10  Running
# Subject10 Stairs
# -----------
# [0.4176, 0.3211, 0.4255, 0.3709, 0.4354, 0.411, 0.3939, 0.402, 0.4414, 0.3616, 0.4304, 0.3868, 0.4592, 0.4297, 0.4741, 0.4661, 0.3755, 0.4675, 0.4624, 0.455, 0.6538, 0.705, 0.63, 0.5814, 0.6375, 0.6432, 0.5794, 0.6315, 0.6645, 0.6378, 0.6057, 0.6069, 0.6758, 0.703, 0.6159, 0.6546, 0.6103, 0.6155, 0.5981, 0.5727, 0.5672, 0.6369, 0.5214, 0.6004, 0.6899, 0.6087, 0.6028, 0.5921, 0.6569, 0.6379, 0.5843, 0.6861, 0.6628, 0.6053, 0.5685, 0.5448, 0.5884, 0.5989, 0.5747, 0.6067]
# [3.8273, 5.4942, 5.0184]
#         ke      ee         Time    Subject Activity
# 0   0.4176  3.8273   360.000000  Subject10   Stairs
# 1   0.3211  3.8273   375.000000  Subject10   Stairs
# 2   0.4255  3.8273   390.000000  Subject10   Stairs
# 3   0.3709  3.8273   405.000000  Subject10   Stairs
# 4   0.4354  3.8273   420.000000  Subject10   Stairs
# 5   0.4110  3.8273   435.000000  Subject10   Stairs
# 6   0.3939  3.8273   450.000000  Subject10   Stairs
# 7   0.4020  3.8273   465.000000  Subject10   Stairs
# 8   0.4414  3.8273   480.000000  Subject10   Stairs
# 9   0.3616  3.8273   495.000000  Subject10   Stairs
# 10  0.4304  3.8273   510.000000  Subject10   Stairs
# 43  5.7637  2.6765  1125.000000  Subject10  Walking
# 44  5.5904  2.6765  1140.000000  Subject10  Walking
# 45  5.5857  2.6765  1155.000000  Subject10  Walking
# 46  5.6082  2.6765  1170.000000  Subject10  Walking
# 47  5.5840  2.6765  1185.000000  Subject10  Walking
# 48  5.5489  2.6765  1200.000000  Subject10  Walking
# 49  5.5831  2.6765  1215.000000  Subject10  Walking
# 50  5.5516  2.6765  1230.000000  Subject10  Walking
# 51  5.4935  2.6765  1245.000000  Subject10  Walking
# 52  5.6195  2.6765  1260.000000  Subject10  Walking
# 53  5.6096  2.6765  1275.000000  Subject10  Walking
# 54  5.5081  2.6765  1290.000000  Subject10  Walking
# 55  5.5737  2.6765  1305.000000  Subject10  Walking
# 56  5.6102  2.6765  1320.000000  Subject10  Walking
# 57  5.6090  2.6765  1335.000000  Subject10  Walking
# 58  5.6543  2.6765  1350.000000  Subject10  Walking
# 59  5.5435  2.6765  1365.000000  Subject10  Walking
# 60  5.5435  2.6765  1440.046875  Subject10  Walking

# %%
pd.set_option('display.max_rows', 4000)
final_df_r = pd.concat(df_list_R, ignore_index=True)
print(final_df_r)
# Out:
#            ke       ee    Time    Subject   Activity
# 0      0.8074   1.3861   360.0  Subject01  Backwards
# 1      0.9266   1.3861   375.0  Subject01  Backwards
# 2      0.9052   1.3861   390.0  Subject01  Backwards
# 3      0.9123   1.3861   405.0  Subject01  Backwards
# 4      0.8525   1.3861   420.0  Subject01  Backwards
# 5      0.8928   1.3861   435.0  Subject01  Backwards
# 6      0.8397   1.3861   450.0  Subject01  Backwards
# 7      0.8608   1.3861   465.0  Subject01  Backwards
# 8      0.8898   1.3861   480.0  Subject01  Backwards
# 9      0.8786   1.3861   495.0  Subject01  Backwards
# 10     0.8772   1.3861   510.0  Subject01  Backwards
# 11     0.8512   1.3861   525.0  Subject01  Backwards
# 12     0.8026   1.3861   540.0  Subject01  Backwards
# 13     0.7973   1.3861   555.0  Subject01  Backwards
# 14     0.8693   1.3861   570.0  Subject01  Backwards
# 15     0.9020   1.3861   585.0  Subject01  Backwards
# 16     0.9184   1.3861   600.0  Subject01  Backwards
# 17     0.8857   1.3861   615.0  Subject01  Backwards
# 18     0.8871   1.3861   630.0  Subject01  Backwards
# 19     0.8334   1.3861   645.0  Subject01  Backwards
# 20     1.7916   2.3818   720.0  Subject01  Backwards
# 21     1.7527   2.3818   735.0  Subject01  Backwards
# 22     1.8168   2.3818   750.0  Subject01  Backwards
# 23     1.8648   2.3818   765.0  Subject01  Backwards
# 24     1.8055   2.3818   780.0  Subject01  Backwards
# 25     1.8374   2.3818   795.0  Subject01  Backwards
# 26     1.8202   2.3818   810.0  Subject01  Backwards
# 27     1.7830   2.3818   825.0  Subject01  Backwards
# 28     1.8393   2.3818   840.0  Subject01  Backwards
# 29     1.7429   2.3818   855.0  Subject01  Backwards
# 30     1.7700   2.3818   870.0  Subject01  Backwards
# 31     1.8270   2.3818   885.0  Subject01  Backwards
# 32     1.7338   2.3818   900.0  Subject01  Backwards
# 33     1.8148   2.3818   915.0  Subject01  Backwards
# 34     1.8033   2.3818   930.0  Subject01  Backwards
# 35     1.7866   2.3818   945.0  Subject01  Backwards
# 36     1.7077   2.3818   960.0  Subject01  Backwards
# 37     1.7049   2.3818   975.0  Subject01  Backwards
# 38     1.7412   2.3818   990.0  Subject01  Backwards
# 39     1.7535   2.3818  1005.0  Subject01  Backwards
# 40     2.6549   3.4005  1080.0  Subject01  Backwards
# 41     2.6127   3.4005  1095.0  Subject01  Backwards
# 42     2.7408   3.4005  1110.0  Subject01  Backwards
# 43     2.6545   3.4005  1125.0  Subject01  Backwards
# 44     2.7541   3.4005  1140.0  Subject01  Backwards
# 45     2.7877   3.4005  1155.0  Subject01  Backwards
# 46     2.7644   3.4005  1170.0  Subject01  Backwards
# 47     2.7528   3.4005  1185.0  Subject01  Backwards
# 48     2.7875   3.4005  1200.0  Subject01  Backwards
# 49     2.8265   3.4005  1215.0  Subject01  Backwards
# 50     2.8375   3.4005  1230.0  Subject01  Backwards
# 51     2.7266   3.4005  1245.0  Subject01  Backwards
# 52     2.7541   3.4005  1260.0  Subject01  Backwards
# 53     2.8069   3.4005  1275.0  Subject01  Backwards
# 54     2.8006   3.4005  1290.0  Subject01  Backwards
# 55     2.8821   3.4005  1305.0  Subject01  Backwards
# 56     2.7455   3.4005  1320.0  Subject01  Backwards
# 57     2.7524   3.4005  1335.0  Subject01  Backwards
# 58     2.6771   3.4005  1350.0  Subject01  Backwards
# 59     2.8561   3.4005  1365.0  Subject01  Backwards
# 60     0.7278   5.2693   360.0  Subject01    Cycling
# 61     2.6390   5.2693   375.0  Subject01    Cycling
# 62     2.7398   5.2693   390.0  Subject01    Cycling
# 63     2.6012   5.2693   405.0  Subject01    Cycling
# 64     2.5135   5.2693   420.0  Subject01    Cycling
# 65     2.6667   5.2693   435.0  Subject01    Cycling
# 66     2.5659   5.2693   450.0  Subject01    Cycling
# 67     2.5826   5.2693   465.0  Subject01    Cycling
# 68     2.6910   5.2693   480.0  Subject01    Cycling
# 69     2.6242   5.2693   495.0  Subject01    Cycling
# 70     2.7283   5.2693   510.0  Subject01    Cycling
# 71     2.7214   5.2693   525.0  Subject01    Cycling
# 72     2.6839   5.2693   540.0  Subject01    Cycling
# 73     2.6444   5.2693   555.0  Subject01    Cycling
# 74     2.6644   5.2693   570.0  Subject01    Cycling
# 75     2.8567   5.2693   585.0  Subject01    Cycling
# 76     2.8704   5.2693   600.0  Subject01    Cycling
# 77     2.7105   5.2693   615.0  Subject01    Cycling
# 78     2.7975   5.2693   630.0  Subject01    Cycling
# 79     2.7786   5.2693   645.0  Subject01    Cycling
# 80     1.6940   5.3118   720.0  Subject01    Cycling
# 81     1.4337   5.3118   735.0  Subject01    Cycling
# 82     1.4136   5.3118   750.0  Subject01    Cycling
# 83     1.4731   5.3118   765.0  Subject01    Cycling
# 84     1.4391   5.3118   780.0  Subject01    Cycling
# 85     1.3652   5.3118   795.0  Subject01    Cycling
# 86     1.4125   5.3118   810.0  Subject01    Cycling
# 141    3.7002   4.3915   375.0  Subject01    Incline
# 142    3.7002   4.3915   390.0  Subject01    Incline
# 143    3.7553   4.3915   405.0  Subject01    Incline
# 144    3.7167   4.3915   420.0  Subject01    Incline
# 145    3.6829   4.3915   435.0  Subject01    Incline
# 146    3.6364   4.3915   450.0  Subject01    Incline
# 147    3.6020   4.3915   465.0  Subject01    Incline
# 148    3.5419   4.3915   480.0  Subject01    Incline
# 149    3.6915   4.3915   495.0  Subject01    Incline
# 150    3.6929   4.3915   510.0  Subject01    Incline
# 151    3.6686   4.3915   525.0  Subject01    Incline
# 152    3.7067   4.3915   540.0  Subject01    Incline
# 153    3.7221   4.3915   555.0  Subject01    Incline
# 154    3.7342   4.3915   570.0  Subject01    Incline
# 155    3.6559   4.3915   585.0  Subject01    Incline
# 156    3.6553   4.3915   600.0  Subject01    Incline
# 157    3.7321   4.3915   615.0  Subject01    Incline
# 158    3.7519   4.3915   630.0  Subject01    Incline
# 159    3.6903   4.3915   645.0  Subject01    Incline
# 160    1.3945   2.1477   720.0  Subject01    Incline
# 161    1.3385   2.1477   735.0  Subject01    Incline
# 162    1.3429   2.1477   750.0  Subject01    Incline
# 163    1.2836   2.1477   765.0  Subject01    Incline
# 164    1.3254   2.1477   780.0  Subject01    Incline
# 165    1.3177   2.1477   795.0  Subject01    Incline
# 166    1.3389   2.1477   810.0  Subject01    Incline
# 167    1.3704   2.1477   825.0  Subject01    Incline
# 168    1.3532   2.1477   840.0  Subject01    Incline
# 169    1.3301   2.1477   855.0  Subject01    Incline
# 170    1.3663   2.1477   870.0  Subject01    Incline
# 171    1.3340   2.1477   885.0  Subject01    Incline
# 172    1.3521   2.1477   900.0  Subject01    Incline
# 173    1.2982   2.1477   915.0  Subject01    Incline
# 174    1.3092   2.1477   930.0  Subject01    Incline
# 175    1.4078   2.1477   945.0  Subject01    Incline
# 176    1.3275   2.1477   960.0  Subject01    Incline
# 177    1.3476   2.1477   975.0  Subject01    Incline
# 178    1.3756   2.1477   990.0  Subject01    Incline
# 179    1.3265   2.1477  1005.0  Subject01    Incline
# 180    0.9336  -0.0283  1080.0  Subject01    Incline
# 181    0.0525  -0.0283  1095.0  Subject01    Incline
# 182    0.0929  -0.0283  1110.0  Subject01    Incline
# 183    0.0185  -0.0283  1125.0  Subject01    Incline
# 184    0.0839  -0.0283  1140.0  Subject01    Incline
# 185    0.0370  -0.0283  1155.0  Subject01    Incline
# 186    0.0463  -0.0283  1170.0  Subject01    Incline
# 187    0.0695  -0.0283  1185.0  Subject01    Incline
# 188    0.0504  -0.0283  1200.0  Subject01    Incline
# 189    0.0343  -0.0283  1215.0  Subject01    Incline
# 190    0.0217  -0.0283  1230.0  Subject01    Incline
# 191    0.0443  -0.0283  1245.0  Subject01    Incline
# 192    0.0631  -0.0283  1260.0  Subject01    Incline
# 193    0.0154  -0.0283  1275.0  Subject01    Incline
# 194    0.0153  -0.0283  1290.0  Subject01    Incline
# 195    0.0112  -0.0283  1305.0  Subject01    Incline
# 196    0.0222  -0.0283  1320.0  Subject01    Incline
# 197    0.0073  -0.0283  1335.0  Subject01    Incline
# 198    0.0176  -0.0283  1350.0  Subject01    Incline
# 199    0.0078  -0.0283  1365.0  Subject01    Incline
# 200    0.8442   3.4060  1440.0  Subject01    Incline
# 201    1.0054   3.4060  1455.0  Subject01    Incline
# 202    1.0471   3.4060  1470.0  Subject01    Incline
# 203    1.0263   3.4060  1485.0  Subject01    Incline
# 204    1.0239   3.4060  1500.0  Subject01    Incline
# 205    1.0205   3.4060  1515.0  Subject01    Incline
# 206    1.0090   3.4060  1530.0  Subject01    Incline
# 207    0.9749   3.4060  1545.0  Subject01    Incline
# 208    0.9733   3.4060  1560.0  Subject01    Incline
# 209    0.9376   3.4060  1575.0  Subject01    Incline
# 210    0.9464   3.4060  1590.0  Subject01    Incline
# 211    0.9845   3.4060  1605.0  Subject01    Incline
# 212    1.0341   3.4060  1620.0  Subject01    Incline
# 213    0.9776   3.4060  1635.0  Subject01    Incline
# 214    1.0118   3.4060  1650.0  Subject01    Incline
# 215    1.0479   3.4060  1665.0  Subject01    Incline
# 216    0.9935   3.4060  1680.0  Subject01    Incline
# 217    1.0456   3.4060  1695.0  Subject01    Incline
# 218    1.1085   3.4060  1710.0  Subject01    Incline
# 219    1.0626   3.4060  1725.0  Subject01    Incline
# 220    2.6325   7.3179  1800.0  Subject01    Incline
# 221    2.7842   7.3179  1815.0  Subject01    Incline
# 222    2.8347   7.3179  1830.0  Subject01    Incline
# 223    2.9034   7.3179  1845.0  Subject01    Incline
# 224    2.8614   7.3179  1860.0  Subject01    Incline
# 225    2.8359   7.3179  1875.0  Subject01    Incline
# 226    2.8814   7.3179  1890.0  Subject01    Incline
# 227    2.8659   7.3179  1905.0  Subject01    Incline
# 228    2.8154   7.3179  1920.0  Subject01    Incline
# 229    2.8524   7.3179  1935.0  Subject01    Incline
# 230    2.8615   7.3179  1950.0  Subject01    Incline
# 231    2.8594   7.3179  1965.0  Subject01    Incline
# 232    2.7818   7.3179  1980.0  Subject01    Incline
# 233    2.8473   7.3179  1995.0  Subject01    Incline
# 234    2.8601   7.3179  2010.0  Subject01    Incline
# 235    2.8873   7.3179  2025.0  Subject01    Incline
# 236    2.8927   7.3179  2040.0  Subject01    Incline
# 237    2.8422   7.3179  2055.0  Subject01    Incline
# 238    2.7631   7.3179  2070.0  Subject01    Incline
# 239    2.7760   7.3179  2085.0  Subject01    Incline
# 240    3.5246   2.1805   360.0  Subject01    Running
# 241    4.0728   2.1805   375.0  Subject01    Running
# 242    4.0743   2.1805   390.0  Subject01    Running
# 243    4.1397   2.1805   405.0  Subject01    Running
# 244    4.1851   2.1805   420.0  Subject01    Running
# 245    4.1156   2.1805   435.0  Subject01    Running
# 246    4.1362   2.1805   450.0  Subject01    Running
# 247    4.1261   2.1805   465.0  Subject01    Running
# 248    4.0707   2.1805   480.0  Subject01    Running
# 249    4.1195   2.1805   495.0  Subject01    Running
# 250    4.1284   2.1805   510.0  Subject01    Running
# 251    4.0435   2.1805   525.0  Subject01    Running
# 252    4.0600   2.1805   540.0  Subject01    Running
# 253    4.1021   2.1805   555.0  Subject01    Running
# 254    4.0833   2.1805   570.0  Subject01    Running
# 255    4.1695   2.1805   585.0  Subject01    Running
# 256    4.1256   2.1805   600.0  Subject01    Running
# 257    4.1073   2.1805   615.0  Subject01    Running
# 258    4.1685   2.1805   630.0  Subject01    Running
# 259    4.0999   2.1805   645.0  Subject01    Running
# 260    6.5897   7.4136   720.0  Subject01    Running
# 261    7.9408   7.4136   735.0  Subject01    Running
# 262    8.0860   7.4136   750.0  Subject01    Running
# 263    7.9612   7.4136   765.0  Subject01    Running
# 264    8.0552   7.4136   780.0  Subject01    Running
# 265    8.0991   7.4136   795.0  Subject01    Running
# 266    8.0269   7.4136   810.0  Subject01    Running
# 267    7.9239   7.4136   825.0  Subject01    Running
# 268    7.9193   7.4136   840.0  Subject01    Running
# 269    8.0328   7.4136   855.0  Subject01    Running
# 270    8.0619   7.4136   870.0  Subject01    Running
# 271    8.0024   7.4136   885.0  Subject01    Running
# 272    8.1547   7.4136   900.0  Subject01    Running
# 273    8.1981   7.4136   915.0  Subject01    Running
# 274    8.1170   7.4136   930.0  Subject01    Running
# 275    8.0497   7.4136   945.0  Subject01    Running
# 276    8.1180   7.4136   960.0  Subject01    Running
# 277    8.1159   7.4136   975.0  Subject01    Running
# 278    8.0815   7.4136   990.0  Subject01    Running
# 279    8.0823   7.4136  1005.0  Subject01    Running
# 280   10.8889   9.4870  1080.0  Subject01    Running
# 281   10.9001   9.4870  1095.0  Subject01    Running
# 282   10.8197   9.4870  1110.0  Subject01    Running
# 283   10.9275   9.4870  1125.0  Subject01    Running
# 284   10.7721   9.4870  1140.0  Subject01    Running
# 285   10.6718   9.4870  1155.0  Subject01    Running
# 286   10.5405   9.4870  1170.0  Subject01    Running
# 287   10.9380   9.4870  1185.0  Subject01    Running
# 288   10.9413   9.4870  1200.0  Subject01    Running
# 289   10.7504   9.4870  1215.0  Subject01    Running
# 290   10.6489   9.4870  1230.0  Subject01    Running
# 291   10.6463   9.4870  1245.0  Subject01    Running
# 292   10.9142   9.4870  1260.0  Subject01    Running
# 293   10.5543   9.4870  1275.0  Subject01    Running
# 294   10.4163   9.4870  1290.0  Subject01    Running
# 295   10.5375   9.4870  1305.0  Subject01    Running
# 296   10.6604   9.4870  1320.0  Subject01    Running
# 297   10.6139   9.4870  1335.0  Subject01    Running
# 298   10.6576   9.4870  1350.0  Subject01    Running
# 299   10.7973   9.4870  1365.0  Subject01    Running
# 300    2.4568   1.8304   360.0  Subject01    Walking
# 301    2.7429   1.8304   375.0  Subject01    Walking
# 302    2.7486   1.8304   390.0  Subject01    Walking
# 303    2.8250   1.8304   405.0  Subject01    Walking
# 304    2.8247   1.8304   420.0  Subject01    Walking
# 305    2.7930   1.8304   435.0  Subject01    Walking
# 306    2.7968   1.8304   450.0  Subject01    Walking
# 307    2.8415   1.8304   465.0  Subject01    Walking
# 308    2.8054   1.8304   480.0  Subject01    Walking
# 309    2.8097   1.8304   495.0  Subject01    Walking
# 310    2.8191   1.8304   510.0  Subject01    Walking
# 311    2.7842   1.8304   525.0  Subject01    Walking
# 312    2.7930   1.8304   540.0  Subject01    Walking
# 313    2.9029   1.8304   555.0  Subject01    Walking
# 314    2.8537   1.8304   570.0  Subject01    Walking
# 315    2.8584   1.8304   585.0  Subject01    Walking
# 316    2.8954   1.8304   600.0  Subject01    Walking
# 317    2.8049   1.8304   615.0  Subject01    Walking
# 318    2.8552   1.8304   630.0  Subject01    Walking
# 319    2.8456   1.8304   645.0  Subject01    Walking
# 320    3.5300   2.2464   720.0  Subject01    Walking
# 321    3.9423   2.2464   735.0  Subject01    Walking
# 322    4.0548   2.2464   750.0  Subject01    Walking
# 323    4.0486   2.2464   765.0  Subject01    Walking
# 324    4.0497   2.2464   780.0  Subject01    Walking
# 325    4.0112   2.2464   795.0  Subject01    Walking
# 326    4.1419   2.2464   810.0  Subject01    Walking
# 327    4.0688   2.2464   825.0  Subject01    Walking
# 328    4.0919   2.2464   840.0  Subject01    Walking
# 329    4.1111   2.2464   855.0  Subject01    Walking
# 330    4.0982   2.2464   870.0  Subject01    Walking
# 331    4.1127   2.2464   885.0  Subject01    Walking
# 332    4.2020   2.2464   900.0  Subject01    Walking
# 333    4.1629   2.2464   915.0  Subject01    Walking
# 334    4.1813   2.2464   930.0  Subject01    Walking
# 335    4.1118   2.2464   945.0  Subject01    Walking
# 336    4.1422   2.2464   960.0  Subject01    Walking
# 337    4.1468   2.2464   975.0  Subject01    Walking
# 338    4.1354   2.2464   990.0  Subject01    Walking
# 339    4.0775   2.2464  1005.0  Subject01    Walking
# 340    1.5108   0.9629  1080.0  Subject01    Walking
# 341    1.4886   0.9629  1095.0  Subject01    Walking
# 342    1.5083   0.9629  1110.0  Subject01    Walking
# 343    1.4702   0.9629  1125.0  Subject01    Walking
# 344    1.5076   0.9629  1140.0  Subject01    Walking
# 345    1.4829   0.9629  1155.0  Subject01    Walking
# 346    1.5043   0.9629  1170.0  Subject01    Walking
# 347    1.5169   0.9629  1185.0  Subject01    Walking
# 348    1.5046   0.9629  1200.0  Subject01    Walking
# 349    1.5526   0.9629  1215.0  Subject01    Walking
# 350    1.4769   0.9629  1230.0  Subject01    Walking
# 351    1.4194   0.9629  1245.0  Subject01    Walking
# 352    1.4857   0.9629  1260.0  Subject01    Walking
# 353    1.4362   0.9629  1275.0  Subject01    Walking
# 354    1.4570   0.9629  1290.0  Subject01    Walking
# 355    1.4608   0.9629  1305.0  Subject01    Walking
# 356    1.4637   0.9629  1320.0  Subject01    Walking
# 357    1.4933   0.9629  1335.0  Subject01    Walking
# 358    1.4407   0.9629  1350.0  Subject01    Walking
# 359    1.5342   0.9629  1365.0  Subject01    Walking
# 360    2.2983   5.9295   360.0  Subject02    Cycling
# 361    3.2449   5.9295   375.0  Subject02    Cycling
# 362    3.0379   5.9295   390.0  Subject02    Cycling
# 363    2.9822   5.9295   405.0  Subject02    Cycling
# 364    2.9505   5.9295   420.0  Subject02    Cycling
# 365    2.8568   5.9295   435.0  Subject02    Cycling
# 366    2.8145   5.9295   450.0  Subject02    Cycling
# 757    1.7024   1.5413  1695.0  Subject02    Walking
# 758    1.6673   1.5413  1710.0  Subject02    Walking
# 759    1.7124   1.5413  1725.0  Subject02    Walking
# 760    1.7649   2.9285   360.0  Subject03  Backwards
# 761    2.2176   2.9285   375.0  Subject03  Backwards
# 762    2.1127   2.9285   390.0  Subject03  Backwards
# 763    2.0914   2.9285   405.0  Subject03  Backwards
# 764    1.8788   2.9285   420.0  Subject03  Backwards
# 765    2.0174   2.9285   435.0  Subject03  Backwards
# 766    2.0093   2.9285   450.0  Subject03  Backwards
# 767    1.9777   2.9285   465.0  Subject03  Backwards
# 768    2.0139   2.9285   480.0  Subject03  Backwards
# 769    2.0481   2.9285   495.0  Subject03  Backwards
# 770    1.9588   2.9285   510.0  Subject03  Backwards
# 771    1.9733   2.9285   525.0  Subject03  Backwards
# 772    1.9408   2.9285   540.0  Subject03  Backwards
# 773    1.9463   2.9285   555.0  Subject03  Backwards
# 774    1.9366   2.9285   570.0  Subject03  Backwards
# 775    1.8584   2.9285   585.0  Subject03  Backwards
# 776    1.8406   2.9285   600.0  Subject03  Backwards
# 777    1.8425   2.9285   615.0  Subject03  Backwards
# 778    1.8717   2.9285   630.0  Subject03  Backwards
# 779    1.8720   2.9285   645.0  Subject03  Backwards
# 780    1.1799   1.9719   720.0  Subject03  Backwards
# 781    1.0525   1.9719   735.0  Subject03  Backwards
# 782    1.2133   1.9719   750.0  Subject03  Backwards
# 783    0.9836   1.9719   765.0  Subject03  Backwards
# 784    1.1155   1.9719   780.0  Subject03  Backwards
# 785    1.1299   1.9719   795.0  Subject03  Backwards
# 786    1.1501   1.9719   810.0  Subject03  Backwards
# 787    1.3169   1.9719   825.0  Subject03  Backwards
# 788    1.1613   1.9719   840.0  Subject03  Backwards
# 789    1.1180   1.9719   855.0  Subject03  Backwards
# 790    1.3089   1.9719   870.0  Subject03  Backwards
# 791    1.2446   1.9719   885.0  Subject03  Backwards
# 792    1.1766   1.9719   900.0  Subject03  Backwards
# 793    1.1548   1.9719   915.0  Subject03  Backwards
# 794    1.2005   1.9719   930.0  Subject03  Backwards
# 795    1.0941   1.9719   945.0  Subject03  Backwards
# 796    1.0665   1.9719   960.0  Subject03  Backwards
# 797    1.1398   1.9719   975.0  Subject03  Backwards
# 798    1.2316   1.9719   990.0  Subject03  Backwards
# 799    1.0123   1.9719  1005.0  Subject03  Backwards
# 800    0.0191   6.6793   360.0  Subject03    Cycling
# 801    2.0354   6.6793   375.0  Subject03    Cycling
# 802    2.6460   6.6793   390.0  Subject03    Cycling
# 803    2.7056   6.6793   405.0  Subject03    Cycling
# 804    2.5980   6.6793   420.0  Subject03    Cycling
# 805    2.7155   6.6793   435.0  Subject03    Cycling
# 806    2.5117   6.6793   450.0  Subject03    Cycling
# 807    2.7173   6.6793   465.0  Subject03    Cycling
# 808    2.7337   6.6793   480.0  Subject03    Cycling
# 809    2.7336   6.6793   495.0  Subject03    Cycling
# 810    2.7225   6.6793   510.0  Subject03    Cycling
# 811    2.8016   6.6793   525.0  Subject03    Cycling
# 3747   1.9090   2.4382   465.0  Subject10    Incline
# 3748   1.9401   2.4382   480.0  Subject10    Incline
# 3749   1.9411   2.4382   495.0  Subject10    Incline
# 3750   2.0402   2.4382   510.0  Subject10    Incline
# 3751   1.9411   2.4382   525.0  Subject10    Incline
# 3752   1.8868   2.4382   540.0  Subject10    Incline
# 3753   1.8872   2.4382   555.0  Subject10    Incline
# 3754   2.0400   2.4382   570.0  Subject10    Incline
# 3755   2.0509   2.4382   585.0  Subject10    Incline
# 3756   2.0853   2.4382   600.0  Subject10    Incline
# 3757   1.8905   2.4382   615.0  Subject10    Incline
# 3758   2.0583   2.4382   630.0  Subject10    Incline
# 3759   2.3080   2.4382   645.0  Subject10    Incline
# 3760   4.1588   4.7357   720.0  Subject10    Incline
# 3761   4.6195   4.7357   735.0  Subject10    Incline
# 3762   4.6825   4.7357   750.0  Subject10    Incline
# 3763   4.8557   4.7357   765.0  Subject10    Incline
# 3764   4.8633   4.7357   780.0  Subject10    Incline
# 3765   4.8281   4.7357   795.0  Subject10    Incline
# 3766   4.8984   4.7357   810.0  Subject10    Incline
# 3767   4.9399   4.7357   825.0  Subject10    Incline
# 3768   4.9595   4.7357   840.0  Subject10    Incline
# 3769   4.8955   4.7357   855.0  Subject10    Incline
# 3770   4.9313   4.7357   870.0  Subject10    Incline
# 3771   4.9795   4.7357   885.0  Subject10    Incline
# 3772   4.9041   4.7357   900.0  Subject10    Incline
# 3773   5.0907   4.7357   915.0  Subject10    Incline
# 3774   4.9159   4.7357   930.0  Subject10    Incline
# 3775   4.9410   4.7357   945.0  Subject10    Incline
# 3776   5.0313   4.7357   960.0  Subject10    Incline
# 3777   5.0796   4.7357   975.0  Subject10    Incline
# 3778   5.0363   4.7357   990.0  Subject10    Incline
# 3779   4.8973   4.7357  1005.0  Subject10    Incline
# 3780   2.3300   0.2764  1080.0  Subject10    Incline
# 3781   0.1742   0.2764  1095.0  Subject10    Incline
# 3782   0.0242   0.2764  1110.0  Subject10    Incline
# 3783   0.0991   0.2764  1125.0  Subject10    Incline
# 3784   0.0099   0.2764  1140.0  Subject10    Incline
# 3785   0.0498   0.2764  1155.0  Subject10    Incline
# 3786   0.0190   0.2764  1170.0  Subject10    Incline
# 3787   0.7080   0.2764  1185.0  Subject10    Incline
# 3788   0.0264   0.2764  1200.0  Subject10    Incline
# 3789   0.0095   0.2764  1215.0  Subject10    Incline
# 3790   0.0118   0.2764  1230.0  Subject10    Incline
# 3791   0.0097   0.2764  1245.0  Subject10    Incline
# 3792   0.0103   0.2764  1260.0  Subject10    Incline
# 3793   0.0149   0.2764  1275.0  Subject10    Incline
# 3794   0.0191   0.2764  1290.0  Subject10    Incline
# 3795   0.0123   0.2764  1305.0  Subject10    Incline
# 3796   0.0141   0.2764  1320.0  Subject10    Incline
# 3797   0.0118   0.2764  1335.0  Subject10    Incline
# 3798   0.0111   0.2764  1350.0  Subject10    Incline
# 3799   0.0099   0.2764  1365.0  Subject10    Incline
# 3800   3.1398   9.2065  1440.0  Subject10    Incline
# 3801   3.9413   9.2065  1455.0  Subject10    Incline
# 3802   3.7952   9.2065  1470.0  Subject10    Incline
# 3803   4.0175   9.2065  1485.0  Subject10    Incline
# 3804   3.8760   9.2065  1500.0  Subject10    Incline
# 3805   3.9550   9.2065  1515.0  Subject10    Incline
# 3806   3.9913   9.2065  1530.0  Subject10    Incline
# 3807   4.0127   9.2065  1545.0  Subject10    Incline
# 3808   3.9859   9.2065  1560.0  Subject10    Incline
# 3809   4.0377   9.2065  1575.0  Subject10    Incline
# 3810   4.0968   9.2065  1590.0  Subject10    Incline
# 3811   3.9635   9.2065  1605.0  Subject10    Incline
# 3812   4.0239   9.2065  1620.0  Subject10    Incline
# 3813   4.0136   9.2065  1635.0  Subject10    Incline
# 3814   4.1388   9.2065  1650.0  Subject10    Incline
# 3815   4.1306   9.2065  1665.0  Subject10    Incline
# 3816   4.0759   9.2065  1680.0  Subject10    Incline
# 3817   4.0334   9.2065  1695.0  Subject10    Incline
# 3818   4.2062   9.2065  1710.0  Subject10    Incline
# 3819   4.1640   9.2065  1725.0  Subject10    Incline
# 3820   2.0891   4.4280  1800.0  Subject10    Incline
# 3821   1.8834   4.4280  1815.0  Subject10    Incline
# 3822   1.8289   4.4280  1830.0  Subject10    Incline
# 3823   1.7971   4.4280  1845.0  Subject10    Incline
# 3824   1.8034   4.4280  1860.0  Subject10    Incline
# 3825   1.8759   4.4280  1875.0  Subject10    Incline
# 3826   1.8327   4.4280  1890.0  Subject10    Incline
# 3827   1.8064   4.4280  1905.0  Subject10    Incline
# 3828   1.7080   4.4280  1920.0  Subject10    Incline
# 3829   1.7303   4.4280  1935.0  Subject10    Incline
# 3830   1.7446   4.4280  1950.0  Subject10    Incline
# 3831   1.8577   4.4280  1965.0  Subject10    Incline
# 3832   1.8153   4.4280  1980.0  Subject10    Incline
# 3833   1.7580   4.4280  1995.0  Subject10    Incline
# 3834   1.7030   4.4280  2010.0  Subject10    Incline
# 3835   1.7668   4.4280  2025.0  Subject10    Incline
# 3836   1.6933   4.4280  2040.0  Subject10    Incline
# 3837   1.7619   4.4280  2055.0  Subject10    Incline
# 3838   1.6672   4.4280  2070.0  Subject10    Incline
# 3839   1.7430   4.4280  2085.0  Subject10    Incline
# 3840   4.1119   2.5287   360.0  Subject10    Running
# 3841   5.6232   2.5287   375.0  Subject10    Running
# 3842   5.7935   2.5287   390.0  Subject10    Running
# 3843   5.6232   2.5287   405.0  Subject10    Running
# 3844   5.7635   2.5287   420.0  Subject10    Running
# 3845   5.7009   2.5287   435.0  Subject10    Running
# 3846   5.6708   2.5287   450.0  Subject10    Running
# 3847   5.8005   2.5287   465.0  Subject10    Running
# 3848   5.8333   2.5287   480.0  Subject10    Running
# 3849   5.9389   2.5287   495.0  Subject10    Running
# 3850   5.7750   2.5287   510.0  Subject10    Running
# 3851   5.8362   2.5287   525.0  Subject10    Running
# 3852   5.7818   2.5287   540.0  Subject10    Running
# 3853   5.7818   2.5287   555.0  Subject10    Running
# 3854   5.6537   2.5287   570.0  Subject10    Running
# 3855   5.7481   2.5287   585.0  Subject10    Running
# 3963   5.7637   2.6765  1125.0  Subject10    Walking
# 3964   5.5904   2.6765  1140.0  Subject10    Walking
# 3965   5.5857   2.6765  1155.0  Subject10    Walking
# 3966   5.6082   2.6765  1170.0  Subject10    Walking
# 3967   5.5840   2.6765  1185.0  Subject10    Walking
# 3968   5.5489   2.6765  1200.0  Subject10    Walking
# 3969   5.5831   2.6765  1215.0  Subject10    Walking
# 3970   5.5516   2.6765  1230.0  Subject10    Walking
# 3971   5.4935   2.6765  1245.0  Subject10    Walking
# 3972   5.6195   2.6765  1260.0  Subject10    Walking
# 3973   5.6096   2.6765  1275.0  Subject10    Walking
# 3974   5.5081   2.6765  1290.0  Subject10    Walking
# 3975   5.5737   2.6765  1305.0  Subject10    Walking
# 3976   5.6102   2.6765  1320.0  Subject10    Walking
# 3977   5.6090   2.6765  1335.0  Subject10    Walking
# 3978   5.6543   2.6765  1350.0  Subject10    Walking
# 3979   5.5435   2.6765  1365.0  Subject10    Walking

# %%
# 20x 15-second average KE per interval
analyzed = set()
subjectName = []
index = -1
df_list = []
df_list_R = []

for subject in result.keys():
    # Skip certain activities
    if subject[0] == "Subject02" and subject[1] in ['Backwards','Backwards2']:
        continue
    if subject[0] == "Subject05" and subject[1] in ['Cycling','Cycling2']:
        continue
    kePoints = []
    wPoints = []
    cPoints = []
    alPoints = []
    arPoints = []
    eePoints = []
    # Initialize/reset DataFrames for each subject
    KE_df = pd.DataFrame()
    KE_means_df = pd.DataFrame(columns=["Segment", "KE_Mean"])
    
    mNorm = mass[index] / 82.2
    
    if subject[0] not in analyzed:
        index += 1
    print(f"{subject[0]} {subject[1]}\n-----------")
    analyzed.add(subject[0])
    
    indDF = globals()[subject[0]].astype(int)

    # Parameters for different segments
    segments = [
        {'Name': 'W',  'I': 0.02654, 'mass': 0, 'dist': 0, 'columns': [5, 6, 7]},     # W
        {'Name': 'C',  'I': 0.33201, 'mass': 0, 'dist': 0, 'columns': [14, 15, 16]},  # C
        {'Name': 'AL', 'I': 0.06397, 'mass': 3.525, 'dist': 0.6154, 'columns': [23, 24, 25]},  # AL
        {'Name': 'AR', 'I': 0.06271, 'mass': 3.525, 'dist': 0.6154, 'columns': [32, 33, 34]}   # AR
    ]

    # Calculate kinetic energy for each segment
    for segment in segments:
        segment_name = segment['Name']
        I = segment['I'] * mNorm
        cols = segment['columns']
        m = segment['mass']
        r = segment['dist']
        
        # Compute omega
        x, y, z = [np.nan_to_num(result[subject[0]][subject[1]]['APDM_Accel']['Data'][:, c], nan=0.0) for c in cols]
        omega = np.sqrt(x**2 + y**2 + z**2)
        KE = 0.5 * (I + (m*(0.5*r)**2)) * omega**2
        KE_df[segment_name] = KE

    # Calculate total kinetic energy
    KE_df['total'] = (KE_df['W'] + KE_df['C'] + KE_df['AL'] + KE_df['AR'])
    num_intervals = len(indDF[subject[1]]) - 1

    samples_per_fifteen = 15 * 128   # 1920 samples in 15 seconds
    bins_per_interval = 20           # 5 minutes × 4 bins/min

    for i in range(num_intervals):
        interval_start = int(indDF[subject[1]][i])
        interval_end = int(indDF[subject[1]][i + 1])

        for b in range(bins_per_interval):
            bin_start = interval_start + b * samples_per_fifteen
            bin_end = bin_start + samples_per_fifteen

            if bin_end <= interval_end:
                mean_tot = round(KE_df['total'].iloc[bin_start:bin_end].mean(), 4)
                mean_w = round(KE_df['W'].iloc[bin_start:bin_end].mean(), 4)
                mean_c = round(KE_df['C'].iloc[bin_start:bin_end].mean(), 4)
                mean_al = round(KE_df['AL'].iloc[bin_start:bin_end].mean(), 4)
                mean_ar = round(KE_df['AR'].iloc[bin_start:bin_end].mean(), 4)
                kePoints.append(mean_tot)
                wPoints.append(mean_w)
                cPoints.append(mean_c)
                alPoints.append(mean_al)
                arPoints.append(mean_ar)
            else:
                break

    # kePoints = [x for x in kePoints if x == x]
    # print(kePoints)

    # Energy expenditure calculations
    timeF = result[subject[0]][subject[1]]['APDM_Accel']['Data'][:, 0]
    ke_slice_start = result[subject[0]][subject[1]]['APDM_Accel']['Data'][0, 0] + indDF[subject[1]][0] / 128
    ke_slice_end = result[subject[0]][subject[1]]['APDM_Accel']['Data'][0, 0] + indDF[subject[1]][5] / 128

    VO2 = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, vo2]
    VCO2 = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, vco2]
    EE = (16.58 * VO2 + 4.15 * VCO2) / mass[0]
    EE_ground = np.zeros(np.size(EE))

    ind = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, code]
    ind = ind[:-1] - ind[1:]
    bool_ind = ind != 0.0
    indShift = np.where(bool_ind)[0]
    indShift = np.concatenate((indShift, [len(ind)]))

    T_first_phase = result[subject[0]][subject[1]]['Metabolics_System']['Data'][indShift[0], 0]
    timeM3_first = T_first_phase - (3 * 60)
    bool_time_first = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, 0] < timeM3_first
    threeMin_first = indShift[0] - np.max(np.where(bool_time_first)[0])

    EE_avg_first = np.mean(EE[indShift[0] - threeMin_first:indShift[0]])

    for i in range(len(indShift)):
        T = result[subject[0]][subject[1]]['Metabolics_System']['Data'][indShift[i], 0]
        timeM3 = T - (3 * 60)
        bool_time = result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, 0] < timeM3
        threeMin = indShift[i] - np.max(np.where(bool_time)[0])

        if i == 0:
            EE_ground[0:indShift[i]] = np.mean(EE[indShift[i] - threeMin:indShift[i]]) - EE_avg_first
            eePoints.append(round(np.mean(EE[indShift[i] - threeMin:indShift[i]] - EE_avg_first), 4))
        elif i == len(indShift) - 1:
            EE_ground[indShift[i - 1]:] = np.mean(EE[-threeMin:]) - EE_avg_first
            eePoints.append(round(np.mean(EE[-threeMin:] - EE_avg_first), 4))
        else:
            EE_ground[indShift[i - 1]:indShift[i] + 1] = np.mean(EE[indShift[i] - threeMin:indShift[i]]) - EE_avg_first
            eePoints.append(round(np.mean(EE[indShift[i] - threeMin:indShift[i]] - EE_avg_first), 4))

    if subject[1] == 'Incline':
        eePoints = eePoints[1:-1]
    if subject[1] != 'Incline':
        eePoints = eePoints[1:-1]

    if len(eePoints) * 20 != len(kePoints):  
        print("Error in " + subject[0] + " " + subject[1])
        continue
    print(eePoints)

    # For plot
    lastNZ = indDF[subject[1]][indDF[subject[1]] != 0].index[-1]
    time_slice = timeF[indDF[subject[1]][0]:indDF[subject[1]][lastNZ]]
    KE_slice = KE_df['total'][indDF[subject[1]][0]:indDF[subject[1]][lastNZ]]

    ke_eeDF = pd.DataFrame({'ke': kePoints, 'w': wPoints, 'c': cPoints, 'al': alPoints, 'ar': arPoints})

    # Repeat EE 20 times per interval
    ke_eeDF['ee'] = np.repeat(eePoints, 20)[:len(ke_eeDF)]

    # Time axis: 15s steps instead of 60s
    ke_eeDF['Time'] = [360 + 15 * i + 60 * ((i) // 20) for i in range(len(kePoints))]

    newRow = ke_eeDF.iloc[-1].to_dict()
    newRow["Time"] = indDF[subject[1]][len(ke_eeDF) // 20] / 128
    ke_eeDF = pd.concat([ke_eeDF, pd.DataFrame([newRow])], ignore_index=True)
    ke_eeDF['Subject'] = subject[0]
    ke_eeDF['Activity'] = subject[1]
    # print(ke_eeDF)

    # fig, ax1 = plt.subplots()
    # color = 'tab:blue'
    # ax1.set_xlabel('Time (s)')
    # ax1.set_ylabel('Kinetic Energy (W/kg)', color=color)
    # ax1.plot(time_slice, KE_slice, color=color)
    # ax1.tick_params(axis='y', labelcolor=color)

    # x = ke_eeDF['Time']
    # y = ke_eeDF['ke']
    # plt.step(x, y, where='post', color='black')

    # ax2 = ax1.twinx()
    # color = 'tab:orange'
    # ax2.set_ylabel('EE Ground (W/kg)', color=color)
    # ax2.plot(result[subject[0]][subject[1]]['Metabolics_System']['Data'][:, 0], EE_ground, '-', color=color)
    # ax2.tick_params(axis='y', labelcolor=color)

    # plt.xlabel('Time (s)')
    # plt.title('Kinetic Energy vs. EE Ground')
    # plt.show()

    if subject[1] == 'Incline':
        df_list.append(ke_eeDF)
    else:
        df_list.append(ke_eeDF)

    df_list_R.append(ke_eeDF[:-1])
# Out:
# Subject01 Backwards
# -----------
# [1.3861, 2.3818, 3.4005]
# Subject01 Cycling
# -----------
# [5.2693, 5.3118, 2.9473, 4.3014]
# Subject01 Incline
# -----------
# [4.3915, 2.1477, -0.0283, 3.406, 7.3179]
# Subject01 Running
# -----------
# [2.1805, 7.4136, 9.487]
# Subject01 Walking
# -----------
# [1.8304, 2.2464, 0.9629]
# Subject02 Cycling
# -----------
# [5.9295, 6.3243, 3.5758, 4.8132]
# Subject02 Incline
# -----------
# [5.7172, 2.9349, 0.2499, 9.6217, 4.8842]
# Subject02 Running
# -----------
# [3.2756, 9.9736, 13.3416, 9.7279]
# Subject02 Stairs
# -----------
# [4.4224, 5.8041, 6.6176]
# Subject02 Walking
# -----------
# [3.9037, 2.5451, 0.2939, 1.5413]
# Subject03 Backwards
# -----------
# [2.9285, 1.9719]
# Subject03 Cycling
# -----------
# [6.6793, 6.4356, 3.9889, 4.921]
# Subject03 Incline
# -----------
# [3.4757, 6.2116, 0.222, 10.2795, 5.9422]
# Subject03 Running
# -----------
# [3.1877, 11.0262, 12.5893, 9.3661]
# Subject03 Stairs
# -----------
# [4.4575, 5.4713, 5.5952]
# Subject03 Walking
# -----------
# [1.9761, 3.4229, 2.6824]
# Subject04 Backwards
# -----------
# [1.2357, 2.1072]
# Subject04 Cycling
# -----------
# [3.9562, 5.3276, 3.0171, 5.7793]
# Subject04 Incline
# -----------
# [2.5002, 5.3252, 0.2518, 10.5005, 5.4443]
# Subject04 Running
# -----------
# [2.1518, 10.2966, 9.0126, 9.8422]
# Subject04 Stairs
# -----------
# [5.9622, 4.5836, 5.4044]
# Subject04 Walking
# -----------
# [1.6658, 1.3328]
# Subject05 Backwards
# -----------
# [2.232, 3.386, 4.8032]
# Subject05 Incline
# -----------
# [5.6088, 2.744, 0.1289, 5.1934, 10.8103]
# Subject05 Running
# -----------
# [2.8884, 10.0767, 13.1853, 8.8465]
# Subject05 Stairs
# -----------
# [7.6464, 5.4741, 7.1485]
# Subject05 Walking
# -----------
# [2.5504, 3.2308, 1.8335]
# Subject06 Backwards
# -----------
# [1.8906, 3.1236]
# Subject06 Cycling
# -----------
# [4.1207, 5.9055, 6.2759, 3.2409]
# Subject06 Incline
# -----------
# [5.0706, 2.8103, -0.0259, 4.7614, 9.8021]
# Subject06 Running
# -----------
# [2.3792, 11.693, 8.6091, 10.0526]
# Subject06 Stairs
# -----------
# [5.4934, 6.3165, 4.5508]
# Subject06 Walking
# -----------
# [1.25, 1.8004, 2.3623]
# Subject07 Backwards
# -----------
# [2.6064, 1.7025]
# Subject07 Cycling
# -----------
# [2.6641, 4.1018, 5.1505, 5.5892]
# Subject07 Incline
# -----------
# [6.2833, 3.7189, 0.2274, 5.5512, 12.0594]
# Subject07 Running
# -----------
# [3.1609, 10.8107, 14.4348, 9.5884]
# Subject07 Stairs
# -----------
# [5.7274, 8.237, 7.4027]
# Subject07 Walking
# -----------
# [3.476, 2.746, 2.2496]
# Subject08 Backwards
# -----------
# [2.2197, 1.6366]
# Subject08 Cycling
# -----------
# [5.5294, 4.5208, 3.1603, 5.6137]
# Subject08 Incline
# -----------
# [5.2712, 2.9647, 0.1414, 4.6158, 9.5841]
# Subject08 Running
# -----------
# [2.7238, 8.3235, 7.2291, 10.5193]
# Subject08 Stairs
# -----------
# [4.8847, 3.5668, 4.6459]
# Subject08 Walking
# -----------
# [2.071, 1.6497, 2.8827]
# Subject09 Backwards
# -----------
# [2.5614, 1.6818]
# Subject09 Cycling
# -----------
# [3.1042, 5.5057, 4.5028, 6.5951]
# Subject09 Incline
# -----------
# [2.8285, 5.6529, 0.2575, 10.374, 5.5281]
# Subject09 Running
# -----------
# [3.2825, 12.9414, 8.5384, 9.9443]
# Subject09 Stairs
# -----------
# [5.3558, 4.6127, 6.0322]
# Subject09 Walking
# -----------
# [3.3898, 1.856, 2.4588]
# Subject10 Backwards
# -----------
# [1.4237, 1.9392]
# Subject10 Cycling
# -----------
# [2.7021, 5.5104, 5.1069, 4.1495]
# Subject10 Incline
# -----------
# [2.4382, 4.7357, 0.2764, 9.2065, 4.428]
# Subject10 Running
# -----------
# [2.5287]
# Subject10 Stairs
# -----------
# [3.8273, 5.4942, 5.0184]
# Subject10 Walking
# -----------
# [2.1259, 1.706, 2.6765]

# %%
pd.set_option('display.max_rows', 4000)
final_df_r = pd.concat(df_list_R, ignore_index=True)
# 3153    Walking
# 3154    Walking
# 3155    Walking
# 3156    Walking
# 3157    Walking
# 3158    Walking
# 3159    Walking
# 3160    Walking
# 3161    Walking
# 3162    Walking
# 3163    Walking
# 3164    Walking
# 3165    Walking
# 3166    Walking
# 3167    Walking
# 3168    Walking
# 3169    Walking
# 3170    Walking
# 3171    Walking
# 3172    Walking
# 3173    Walking
# 3174    Walking
# 3175    Walking
# 3176    Walking
# 3177    Walking
# 3178    Walking
# 3179    Walking
# 3180    Walking
# 3181    Walking
# 3182    Walking
# 3183    Walking
# 3184    Walking
# 3185    Walking
# 3186    Walking
# 3187    Walking
# 3188    Walking
# 3189    Walking
# 3190    Walking
# 3191    Walking
# 3192    Walking
# 3193    Walking
# 3194    Walking
# 3195    Walking
# 3196    Walking
# 3197    Walking
# 3198    Walking
# 3199    Walking
# 3200  Backwards
# 3201  Backwards
# 3202  Backwards
# 3203  Backwards
# 3204  Backwards
# 3205  Backwards
# 3206  Backwards
# 3207  Backwards
# 3208  Backwards
# 3209  Backwards
# 3210  Backwards
# 3211  Backwards
# 3212  Backwards
# 3213  Backwards
# 3214  Backwards
# 3215  Backwards
# 3216  Backwards
# 3217  Backwards
# 3218  Backwards
# 3219  Backwards
# 3220  Backwards
# 3221  Backwards
# 3222  Backwards
# 3223  Backwards
# 3224  Backwards
# 3225  Backwards
# 3226  Backwards
# 3227  Backwards
# 3228  Backwards
# 3229  Backwards
# 3230  Backwards
# 3231  Backwards
# 3232  Backwards
# 3233  Backwards
# 3234  Backwards
# 3235  Backwards
# 3236  Backwards
# 3237  Backwards
# 3238  Backwards
# 3239  Backwards
# 3240    Cycling
# 3241    Cycling
# 3242    Cycling
# 3243    Cycling
# 3244    Cycling
# 3245    Cycling
# 3246    Cycling
# 3247    Cycling
# 3248    Cycling
# 3249    Cycling
# 3250    Cycling
# 3251    Cycling
# 3252    Cycling
# 3253    Cycling
# 3254    Cycling
# 3255    Cycling
# 3256    Cycling
# 3257    Cycling
# 3258    Cycling
# 3259    Cycling
# 3260    Cycling
# 3261    Cycling
# 3262    Cycling
# 3263    Cycling
# 3264    Cycling
# 3265    Cycling
# 3266    Cycling
# 3267    Cycling
# 3268    Cycling
# 3269    Cycling
# 3270    Cycling
# 3271    Cycling
# 3272    Cycling
# 3273    Cycling
# 3274    Cycling
# 3275    Cycling
# 3276    Cycling
# 3277    Cycling
# 3278    Cycling
# 3279    Cycling
# 3280    Cycling
# 3281    Cycling
# 3282    Cycling
# 3283    Cycling
# 3284    Cycling
# 3285    Cycling
# 3286    Cycling
# 3287    Cycling
# 3288    Cycling
# 3289    Cycling
# 3290    Cycling
# 3291    Cycling
# 3292    Cycling
# 3293    Cycling
# 3294    Cycling
# 3295    Cycling
# 3296    Cycling
# 3297    Cycling
# 3298    Cycling
# 3299    Cycling
# 3300    Cycling
# 3301    Cycling
# 3302    Cycling
# 3303    Cycling
# 3304    Cycling
# 3305    Cycling
# 3306    Cycling
# 3307    Cycling
# 3308    Cycling
# 3309    Cycling
# 3310    Cycling
# 3311    Cycling
# 3312    Cycling
# 3313    Cycling
# 3314    Cycling
# 3315    Cycling
# 3316    Cycling
# 3317    Cycling
# 3318    Cycling
# 3319    Cycling
# 3320    Incline
# 3321    Incline
# 3322    Incline
# 3323    Incline
# 3324    Incline
# 3325    Incline
# 3326    Incline
# 3327    Incline
# 3328    Incline
# 3329    Incline
# 3330    Incline
# 3331    Incline
# 3332    Incline
# 3333    Incline
# 3334    Incline
# 3335    Incline
# 3336    Incline
# 3337    Incline
# 3338    Incline
# 3339    Incline
# 3340    Incline
# 3341    Incline
# 3342    Incline
# 3343    Incline
# 3344    Incline
# 3345    Incline
# 3346    Incline
# 3347    Incline
# 3348    Incline
# 3349    Incline
# 3350    Incline
# 3351    Incline
# 3352    Incline
# 3353    Incline
# 3354    Incline
# 3355    Incline
# 3356    Incline
# 3357    Incline
# 3358    Incline
# 3359    Incline
# 3360    Incline
# 3361    Incline
# 3362    Incline
# 3363    Incline
# 3364    Incline
# 3365    Incline
# 3366    Incline
# 3367    Incline
# 3368    Incline
# 3369    Incline
# 3370    Incline
# 3371    Incline
# 3372    Incline
# 3373    Incline
# 3374    Incline
# 3375    Incline
# 3376    Incline
# 3377    Incline
# 3378    Incline
# 3379    Incline
# 3380    Incline
# 3381    Incline
# 3382    Incline
# 3383    Incline
# 3384    Incline
# 3385    Incline
# 3386    Incline
# 3387    Incline
# 3388    Incline
# 3389    Incline
# 3390    Incline
# 3391    Incline
# 3392    Incline
# 3393    Incline
# 3394    Incline
# 3395    Incline
# 3396    Incline
# 3397    Incline
# 3398    Incline
# 3399    Incline
# 3400    Incline
# 3401    Incline
# 3402    Incline
# 3403    Incline
# 3404    Incline
# 3405    Incline
# 3406    Incline
# 3407    Incline
# 3408    Incline
# 3409    Incline
# 3410    Incline
# 3411    Incline
# 3412    Incline
# 3413    Incline
# 3414    Incline
# 3415    Incline
# 3416    Incline
# 3417    Incline
# 3418    Incline
# 3419    Incline
# 3420    Running
# 3421    Running
# 3422    Running
# 3423    Running
# 3424    Running
# 3425    Running
# 3426    Running
# 3427    Running
# 3428    Running
# 3429    Running
# 3430    Running
# 3431    Running
# 3432    Running
# 3433    Running
# 3434    Running
# 3435    Running
# 3436    Running
# 3437    Running
# 3438    Running
# 3439    Running
# 3440    Running
# 3441    Running
# 3442    Running
# 3443    Running
# 3444    Running
# 3445    Running
# 3446    Running
# 3447    Running
# 3448    Running
# 3449    Running
# 3450    Running
# 3451    Running
# 3452    Running
# 3453    Running
# 3454    Running
# 3455    Running
# 3456    Running
# 3457    Running
# 3458    Running
# 3459    Running
# 3460    Running
# 3461    Running
# 3462    Running
# 3463    Running
# 3464    Running
# 3465    Running
# 3466    Running
# 3467    Running
# 3468    Running
# 3469    Running
# 3470    Running
# 3471    Running
# 3472    Running
# 3473    Running
# 3474    Running
# 3475    Running
# 3476    Running
# 3477    Running
# 3478    Running
# 3479    Running
# 3480    Running
# 3481    Running
# 3482    Running
# 3483    Running
# 3484    Running
# 3485    Running
# 3486    Running
# 3487    Running
# 3488    Running
# 3489    Running
# 3490    Running
# 3491    Running
# 3492    Running
# 3493    Running
# 3494    Running
# 3495    Running
# 3496    Running
# 3497    Running
# 3498    Running
# 3499    Running
# 3500     Stairs
# 3501     Stairs
# 3502     Stairs
# 3503     Stairs
# 3504     Stairs
# 3505     Stairs
# 3506     Stairs
# 3507     Stairs
# 3508     Stairs
# 3509     Stairs
# 3510     Stairs
# 3511     Stairs
# 3512     Stairs
# 3513     Stairs
# 3514     Stairs
# 3515     Stairs
# 3516     Stairs
# 3517     Stairs
# 3518     Stairs
# 3519     Stairs
# 3520     Stairs
# 3521     Stairs
# 3522     Stairs
# 3523     Stairs
# 3524     Stairs
# 3525     Stairs
# 3526     Stairs
# 3527     Stairs
# 3528     Stairs
# 3529     Stairs
# 3530     Stairs
# 3531     Stairs
# 3532     Stairs
# 3533     Stairs
# 3534     Stairs
# 3535     Stairs
# 3536     Stairs
# 3537     Stairs
# 3538     Stairs
# 3539     Stairs
# 3540     Stairs
# 3541     Stairs
# 3542     Stairs
# 3543     Stairs
# 3544     Stairs
# 3545     Stairs
# 3546     Stairs
# 3547     Stairs
# 3548     Stairs
# 3549     Stairs
# 3550     Stairs
# 3551     Stairs
# 3552     Stairs
# 3553     Stairs
# 3554     Stairs
# 3555     Stairs
# 3556     Stairs
# 3557     Stairs
# 3558     Stairs
# 3559     Stairs
# 3560    Walking
# 3561    Walking
# 3562    Walking
# 3563    Walking
# 3564    Walking
# 3565    Walking
# 3566    Walking
# 3567    Walking
# 3568    Walking
# 3569    Walking
# 3570    Walking
# 3571    Walking
# 3572    Walking
# 3573    Walking
# 3574    Walking
# 3575    Walking
# 3576    Walking
# 3577    Walking
# 3578    Walking
# 3579    Walking
# 3580    Walking
# 3581    Walking
# 3582    Walking
# 3583    Walking
# 3584    Walking
# 3585    Walking
# 3586    Walking
# 3587    Walking
# 3588    Walking
# 3589    Walking
# 3590    Walking
# 3591    Walking
# 3592    Walking
# 3593    Walking
# 3594    Walking
# 3595    Walking
# 3596    Walking
# 3597    Walking
# 3598    Walking
# 3599    Walking
# 3600    Walking
# 3601    Walking
# 3602    Walking
# 3603    Walking
# 3604    Walking
# 3605    Walking
# 3606    Walking
# 3607    Walking
# 3608    Walking
# 3609    Walking
# 3610    Walking
# 3611    Walking
# 3612    Walking
# 3613    Walking
# 3614    Walking
# 3615    Walking
# 3616    Walking
# 3617    Walking
# 3618    Walking
# 3619    Walking
# 3620  Backwards
# 3621  Backwards
# 3622  Backwards
# 3623  Backwards
# 3624  Backwards
# 3625  Backwards
# 3626  Backwards
# 3627  Backwards
# 3628  Backwards
# 3629  Backwards
# 3630  Backwards
# 3631  Backwards
# 3632  Backwards
# 3633  Backwards
# 3634  Backwards
# 3635  Backwards
# 3636  Backwards
# 3637  Backwards
# 3638  Backwards
# 3639  Backwards
# 3640  Backwards
# 3641  Backwards
# 3642  Backwards
# 3643  Backwards
# 3644  Backwards
# 3645  Backwards
# 3646  Backwards
# 3647  Backwards
# 3648  Backwards
# 3649  Backwards
# 3650  Backwards
# 3651  Backwards
# 3652  Backwards
# 3653  Backwards
# 3654  Backwards
# 3655  Backwards
# 3656  Backwards
# 3657  Backwards
# 3658  Backwards
# 3659  Backwards
# 3660    Cycling
# 3661    Cycling
# 3662    Cycling
# 3663    Cycling
# 3664    Cycling
# 3665    Cycling
# 3666    Cycling
# 3667    Cycling
# 3668    Cycling
# 3669    Cycling
# 3670    Cycling
# 3671    Cycling
# 3672    Cycling
# 3673    Cycling
# 3674    Cycling
# 3675    Cycling
# 3676    Cycling
# 3677    Cycling
# 3678    Cycling
# 3679    Cycling
# 3680    Cycling
# 3681    Cycling
# 3682    Cycling
# 3683    Cycling
# 3684    Cycling
# 3685    Cycling
# 3686    Cycling
# 3687    Cycling
# 3688    Cycling
# 3689    Cycling
# 3690    Cycling
# 3691    Cycling
# 3692    Cycling
# 3693    Cycling
# 3694    Cycling
# 3695    Cycling
# 3696    Cycling
# 3697    Cycling
# 3698    Cycling
# 3699    Cycling
# 3700    Cycling
# 3701    Cycling
# 3702    Cycling
# 3703    Cycling
# 3704    Cycling
# 3705    Cycling
# 3706    Cycling
# 3707    Cycling
# 3708    Cycling
# 3709    Cycling
# 3710    Cycling
# 3711    Cycling
# 3712    Cycling
# 3713    Cycling
# 3714    Cycling
# 3715    Cycling
# 3716    Cycling
# 3717    Cycling
# 3718    Cycling
# 3719    Cycling
# 3720    Cycling
# 3721    Cycling
# 3722    Cycling
# 3723    Cycling
# 3724    Cycling
# 3725    Cycling
# 3726    Cycling
# 3727    Cycling
# 3728    Cycling
# 3729    Cycling
# 3730    Cycling
# 3731    Cycling
# 3732    Cycling
# 3733    Cycling
# 3734    Cycling
# 3735    Cycling
# 3736    Cycling
# 3737    Cycling
# 3738    Cycling
# 3739    Cycling
# 3740    Incline
# 3741    Incline
# 3742    Incline
# 3743    Incline
# 3744    Incline
# 3745    Incline
# 3746    Incline
# 3747    Incline
# 3748    Incline
# 3749    Incline
# 3750    Incline
# 3751    Incline
# 3752    Incline
# 3753    Incline
# 3754    Incline
# 3755    Incline
# 3756    Incline
# 3757    Incline
# 3758    Incline
# 3759    Incline
# 3760    Incline
# 3761    Incline
# 3762    Incline
# 3763    Incline
# 3764    Incline
# 3765    Incline
# 3766    Incline
# 3767    Incline
# 3768    Incline
# 3769    Incline
# 3770    Incline
# 3771    Incline
# 3772    Incline
# 3773    Incline
# 3774    Incline
# 3775    Incline
# 3776    Incline
# 3777    Incline
# 3778    Incline
# 3779    Incline
# 3780    Incline
# 3781    Incline
# 3782    Incline
# 3783    Incline
# 3784    Incline
# 3785    Incline
# 3786    Incline
# 3787    Incline
# 3788    Incline
# 3789    Incline
# 3790    Incline
# 3791    Incline
# 3792    Incline
# 3793    Incline
# 3794    Incline
# 3795    Incline
# 3796    Incline
# 3797    Incline
# 3798    Incline
# 3799    Incline
# 3800    Incline
# 3801    Incline
# 3802    Incline
# 3803    Incline
# 3804    Incline
# 3805    Incline
# 3806    Incline
# 3807    Incline
# 3808    Incline
# 3809    Incline
# 3810    Incline
# 3811    Incline
# 3812    Incline
# 3813    Incline
# 3814    Incline
# 3815    Incline
# 3816    Incline
# 3817    Incline
# 3818    Incline
# 3819    Incline
# 3820    Incline
# 3821    Incline
# 3822    Incline
# 3823    Incline
# 3824    Incline
# 3825    Incline
# 3826    Incline
# 3827    Incline
# 3828    Incline
# 3829    Incline
# 3830    Incline
# 3831    Incline
# 3832    Incline
# 3833    Incline
# 3834    Incline
# 3835    Incline
# 3836    Incline
# 3837    Incline
# 3838    Incline
# 3839    Incline
# 3840    Running
# 3841    Running
# 3842    Running
# 3843    Running
# 3844    Running
# 3845    Running
# 3846    Running
# 3847    Running
# 3848    Running
# 3849    Running
# 3850    Running
# 3851    Running
# 3852    Running
# 3853    Running
# 3854    Running
# 3855    Running
# 3856    Running
# 3857    Running
# 3858    Running
# 3859    Running
# 3860     Stairs
# 3861     Stairs
# 3862     Stairs
# 3863     Stairs
# 3864     Stairs
# 3865     Stairs
# 3866     Stairs
# 3867     Stairs
# 3868     Stairs
# 3869     Stairs
# 3870     Stairs
# 3871     Stairs
# 3872     Stairs
# 3873     Stairs
# 3874     Stairs
# 3875     Stairs
# 3876     Stairs
# 3877     Stairs
# 3878     Stairs
# 3879     Stairs
# 3880     Stairs
# 3881     Stairs
# 3882     Stairs
# 3883     Stairs
# 3884     Stairs
# 3885     Stairs
# 3886     Stairs
# 3887     Stairs
# 3888     Stairs
# 3889     Stairs
# 3890     Stairs
# 3891     Stairs
# 3892     Stairs
# 3893     Stairs
# 3894     Stairs
# 3895     Stairs
# 3896     Stairs
# 3897     Stairs
# 3898     Stairs
# 3899     Stairs
# 3900     Stairs
# 3901     Stairs
# 3902     Stairs
# 3903     Stairs
# 3904     Stairs
# 3905     Stairs
# 3906     Stairs
# 3907     Stairs
# 3908     Stairs
# 3909     Stairs
# 3910     Stairs
# 3911     Stairs
# 3912     Stairs
# 3913     Stairs
# 3914     Stairs
# 3915     Stairs
# 3916     Stairs
# 3917     Stairs
# 3918     Stairs
# 3919     Stairs
# 3920    Walking
# 3921    Walking
# 3922    Walking
# 3923    Walking
# 3924    Walking
# 3925    Walking
# 3926    Walking
# 3927    Walking
# 3928    Walking
# 3929    Walking
# 3930    Walking
# 3931    Walking
# 3932    Walking
# 3933    Walking
# 3934    Walking
# 3935    Walking
# 3936    Walking
# 3937    Walking
# 3938    Walking
# 3939    Walking
# 3940    Walking
# 3941    Walking
# 3942    Walking
# 3943    Walking
# 3944    Walking
# 3945    Walking
# 3946    Walking
# 3947    Walking
# 3948    Walking
# 3949    Walking
# 3950    Walking
# 3951    Walking
# 3952    Walking
# 3953    Walking
# 3954    Walking
# 3955    Walking
# 3956    Walking
# 3957    Walking
# 3958    Walking
# 3959    Walking
# 3960    Walking
# 3961    Walking
# 3962    Walking
# 3963    Walking
# 3964    Walking
# 3965    Walking
# 3966    Walking
# 3967    Walking
# 3968    Walking
# 3969    Walking
# 3970    Walking
# 3971    Walking
# 3972    Walking
# 3973    Walking
# 3974    Walking
# 3975    Walking
# 3976    Walking
# 3977    Walking
# 3978    Walking
# 3979    Walking
